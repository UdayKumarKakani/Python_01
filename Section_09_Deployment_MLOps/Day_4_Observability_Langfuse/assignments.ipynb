# %% [markdown]
# # Day 4 — Assignments

# %% [markdown]
# ## Exercise 1 — Instrument your RAG
#
# Take any of your Section 6 code. Add `@lf.observe` decorators to `retrieve` and `generate`. Run 5 queries. Screenshot the trace tree in Langfuse.

# %%
# your code

# %% [markdown]
# ## Exercise 2 — User-tagged traces
#
# Simulate two users hitting your app. Tag traces with different `user_id`s. Filter the Langfuse UI by user and confirm the isolation.

# %%
# your code

# %% [markdown]
# ## Stretch — Auto-scoring with LLM-as-judge
#
# Every 5th response, send it to openai/gpt-oss-20b with the judge prompt from Section 8 Day 4. Post the score back via `lf.score(...)`.

# %%
# your code
