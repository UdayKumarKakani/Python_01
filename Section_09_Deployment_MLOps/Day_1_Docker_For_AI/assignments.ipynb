# %% [markdown]
# # Day 1 — Assignments

# %% [markdown]
# ## Exercise 1 — Dockerize your Section 6 chatbot
#
# Copy the `Section_06_RAG_Engineering/Day_6_Capstone_RAG_Chatbot/main.py` into a fresh folder. Write a `Dockerfile` + `.dockerignore`. Build and run. Verify the `/docs` page opens at http://localhost:8000/docs.

# %% [markdown]
# ## Exercise 2 — Image size report
#
# Run `docker image ls` before and after your build. Report the final image size. If it's over 1 GB, use `.dockerignore` to trim it.

# %% [markdown]
# ## Stretch — Multi-stage
#
# Convert your Dockerfile to a multi-stage build. Report the size difference.
