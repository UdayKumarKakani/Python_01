# %% [markdown]
# # Day 3 — Assignments

# %% [markdown]
# ## Exercise 1 — Deploy to Render
#
# Deploy your Day 1/2 project to Render. Get a public URL. Add your `TOGETHER_API_KEY` as an env var. Curl the `/docs` URL and confirm it responds.

# %% [markdown]
# ## Exercise 2 — `render.yaml`
#
# Commit a `render.yaml` with a `/healthz` health check. Confirm Render picks it up on the next push.

# %% [markdown]
# ## Stretch — Gradio on HF Spaces
#
# Wrap your Section 6 `/ask` endpoint call in a Gradio ChatInterface. Deploy to a Hugging Face Space. Share the URL.
