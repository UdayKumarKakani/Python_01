# %% [markdown]
# # Day 5 — Assignments

# %% [markdown]
# ## Exercise 1 — Usage table
#
# Add a `usage` SQLite table to your Section 6 chatbot. Log every LLM call with tokens + cost. Add a `/usage` endpoint returning today's totals.

# %%
# your code

# %% [markdown]
# ## Exercise 2 — Daily cap dependency
#
# Add a FastAPI dependency that returns 429 when the current user has spent >$0.10 today. Test by hitting the endpoint repeatedly.

# %%
# your code

# %% [markdown]
# ## Stretch — Two-prompt A/B
#
# Add a `variant` column. Serve prompt A to half your users, prompt B to the other half. After 20 requests each, compare average tokens + a manual "which felt better" score.

# %%
# your code
