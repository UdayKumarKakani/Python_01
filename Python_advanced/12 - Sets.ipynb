# %% [markdown]
# # Sets

# %% [markdown]
# -> A set is an unordered collection of items. Every element is unique (no duplicates).
#
# -> The set itself is mutable. We can add or remove items from it.
#
# -> Sets can be used to perform mathematical set operations like union, intersection, symmetric difference etc.

# %% [markdown]
# # Set Creation

# %%
#set of integers
s = {1, 2, 3}
print(s)

#print type of s 
print(type(s))
# Out:
# set([1, 2, 3])
# <type 'set'>

# %%
#set doesn't allow duplicates. They store only one instance.
s = {1, 2, 3, 1, 4}
print(s)
# Out:
# {1, 2, 3, 4}

# %%
#we can make set from a list
s = set([1, 2, 3, 1])
print(s)
# Out:
# {1, 2, 3}

# %%
#initialize a set  with set() method
s = set()

print(type(s))
# Out:
# <class 'set'>

# %% [markdown]
# # Add element to a Set

# %%
#we can add single element using add() method and 
#add multiple elements using update() method
s = {1, 3}

#set object doesn't support indexing
print(s[1]) #will get TypeError
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-c52fc339e293> in <module>()
#       4
#       5 #set object doesn't support indexing
# ----> 6 print(s[1]) #will get TypeError
#
# TypeError: 'set' object does not support indexing

# %%
#add element
s.add(2)
print(s)
# Out:
# {1, 2, 3}

# %%
#add multiple elements
s.update([5, 6, 1])
print(s)
# Out:
# {1, 2, 3, 5, 6}

# %%
#add list and set
s.update([8, 9], {10, 2, 3})
print(s)
# Out:
# {1, 2, 3, 5, 6, 8, 9, 10}

# %% [markdown]
# # Remove elements from a Set

# %%
#A particular item can be removed from set using methods, 
#discard() and remove().

s = {1, 2, 3, 5, 4}
print(s)

s.discard(4)    #4 is removed from set s

print(s)
# Out:
# {1, 2, 3, 4, 5}
# {1, 2, 3, 5}

# %%
#remove an element 
s.remove(2)

print(s)
# Out:
# {1, 3, 5}

# %%
#remove an element not present in a set s
s.remove(7) # will get KeyError
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-f37cc9806699> in <module>()
#       1 #remove an element not present in a set s
# ----> 2 s.remove(7) # will get KeyError
#
# KeyError: 7

# %%
#discard an element not present in a set s
s.discard(7)
print(s)
# Out:
# {1, 3, 5}

# %%
#we can remove item using pop() method

s = {1, 2, 3, 5, 4}

s.pop() #remove random element

print(s)
# Out:
# {2, 3, 4, 5}

# %%
s.pop() 
print(s)
# Out:
# {3, 4, 5}

# %%
s = {1, 5, 2, 3, 6}

s.clear()   #remove all items in set using clear() method

print(s)
# Out:
# set()

# %% [markdown]
# # Python Set Operations

# %%
set1 = {1, 2, 3, 4, 5}
set2 = {3, 4, 5, 6, 7}

#union of 2 sets using | operator

print(set1 | set2)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
#another way of getting union of 2 sets
print(set1.union(set2))
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
#intersection of 2 sets using & operator
print(set1 & set2)
# Out:
# {3, 4, 5}

# %%
#use intersection function 
print(set1.intersection(set2))
# Out:
# {3, 4, 5}

# %%
#set Difference: set of elements that are only in set1 but not in set2

print(set1 - set2)
# Out:
# {1, 2}

# %%
#use differnce function 
print(set1.difference(set2))
# Out:
# {1, 2}

# %%
"""symmetric difference: set of elements in both set1 and set2 
#except those that are common in both."""

#use ^ operator

print(set1^set2)
# Out:
# {1, 2, 6, 7}

# %%
#use symmetric_difference function
print(set1.symmetric_difference(set2))
# Out:
# {1, 2, 6, 7}

# %%
#find issubset()
x = {"a","b","c","d","e"}
y = {"c","d"}

print("set 'x' is subset of 'y' ?", x.issubset(y)) #check x is subset of y

#check y is subset of x
print("set 'y' is subset of 'x' ?", y.issubset(x))
# Out:
# set 'x' is subset of 'y' ? False
# set 'y' is subset of 'x' ? True

# %% [markdown]
# # Frozen Sets

# %% [markdown]
# Frozen sets has the characteristics of sets, but we can't be changed once it's assigned. While tuple are immutable lists, frozen sets are immutable sets

# %% [markdown]
# Frozensets can be created using the function frozenset()

# %% [markdown]
# Sets being mutable are unhashable, so they can't be used as dictionary keys. On the other hand, frozensets are hashable and can be used as keys to a dictionary.

# %% [markdown]
# This datatype supports methods like copy(), difference(), intersection(), isdisjoint(), issubset(), issuperset(), symmetric_difference() and union(). Being immutable it does not have method that add or remove elements.

# %%
set1 = frozenset([1, 2, 3, 4])
set2 = frozenset([3, 4, 5, 6])

#try to add element into set1 gives an error
set1.add(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-8f5ea3d0c7e1> in <module>()
#       3
#       4 #try to add element into set1 gives an error
# ----> 5 set1.add(5)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
print(set1[1]) # frozen set doesn't support indexing
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-8fc108f08ec8> in <module>()
# ----> 1 print(set1[1]) # frozen set doesn't support indexing
#
# TypeError: 'frozenset' object does not support indexing

# %%
print(set1 | set2) #union of 2 sets
# Out:
# frozenset({1, 2, 3, 4, 5, 6})

# %%
#intersection of two sets
print(set1 & set2)

#or 
print(set1.intersection(set2))
# Out:
# frozenset({3, 4})
# frozenset({3, 4})

# %%
#symmetric difference
print(set1 ^ set2)

#or
print(set1.symmetric_difference(set2))
# Out:
# frozenset({1, 2, 5, 6})
# frozenset({1, 2, 5, 6})

# %% [markdown]
# ---
# ## Set Operations Reference
#
# | Operation | Operator | Method | Result |
# |-----------|----------|--------|--------|
# | Union | `a \| b` | `a.union(b)` | All unique items in either set |
# | Intersection | `a & b` | `a.intersection(b)` | Items in **both** sets |
# | Difference | `a - b` | `a.difference(b)` | Items in `a` but not `b` |
# | Symmetric Diff | `a ^ b` | `a.symmetric_difference(b)` | Items in either but not both |
# | Subset check | `a <= b` | `a.issubset(b)` | True if every item in `a` is in `b` |
# | Superset check | `a >= b` | `a.issuperset(b)` | True if `a` contains all items of `b` |
# | Disjoint check | — | `a.isdisjoint(b)` | True if no common items |

# %% [markdown]
# ---
# ## Why Use Sets? — Real-World Use Cases
#
# 1. **Remove duplicates fast** — `list(set(my_list))`
# 2. **Fast membership test** — `x in my_set` is **O(1)** vs `x in my_list` which is O(n)
# 3. **Compare collections** — find common / unique items between two groups
#
# ```python
# # Remove duplicates from a list
# nums = [1, 2, 2, 3, 3, 3, 4]
# unique = list(set(nums))
# print(unique)   # [1, 2, 3, 4]
#
# # Find common users between two groups
# group_a = {"alice", "bob", "carol"}
# group_b = {"bob", "dave", "carol"}
# print("In both:", group_a & group_b)        # common
# print("Only in A:", group_a - group_b)      # exclusive to A
# ```

# %% [markdown]
# ---
# # 📝 Assignments – Sets
# ---

# %% [markdown]
# ## Task 1 – Remove Duplicates from a List
#
# **Problem:** Given `nums = [1, 2, 2, 3, 4, 4, 5, 5, 5, 6]`, use a set to get a list of unique numbers.
#
# **Expected output:** `[1, 2, 3, 4, 5, 6]` (order may vary)
#
# **💡 Hint:** `list(set(nums))`

# %%
# Task 1 – Remove Duplicates
nums = [1, 2, 2, 3, 4, 4, 5, 5, 5, 6]
unique = []  # your code here
print(unique)

# %% [markdown]
# ## Task 2 – Union and Intersection of Two Classes
#
# **Problem:** Two classes have the following students:
# ```python
# math_class = {"Alice", "Bob", "Carol", "David"}
# science_class = {"Carol", "David", "Eve", "Frank"}
# ```
# 1. Find students in **either** class (union)
# 2. Find students in **both** classes (intersection)
#
# **Expected output:**
# ```
# Either class: {'Alice', 'Bob', 'Carol', 'David', 'Eve', 'Frank'}
# Both classes: {'Carol', 'David'}
# ```
#
# **💡 Hint:** Use `|` for union, `&` for intersection

# %%
# Task 2 – Union and Intersection
math_class = {"Alice", "Bob", "Carol", "David"}
science_class = {"Carol", "David", "Eve", "Frank"}
# your code here

# %% [markdown]
# ## Task 3 – Difference: Who Only Took Math?
#
# **Problem:** Using the same two sets, find students who took **only Math** (not Science).
#
# **Expected output:** `{'Alice', 'Bob'}`
#
# **💡 Hint:** `math_class - science_class`

# %%
# Task 3 – Difference
math_class = {"Alice", "Bob", "Carol", "David"}
science_class = {"Carol", "David", "Eve", "Frank"}
only_math = set()  # your code here
print(only_math)

# %% [markdown]
# ## Task 4 – Unique Words in a Sentence
#
# **Problem:** Given the sentence:
# `text = "the quick brown fox jumps over the lazy dog the fox is quick"`
# Find the number of **unique** words.
#
# **Expected output:** `Unique word count: 9`
#
# **💡 Hint:** Use `text.split()` then convert to a `set` and use `len()`

# %%
# Task 4 – Unique Words
text = "the quick brown fox jumps over the lazy dog the fox is quick"
# your code here

# %% [markdown]
# ## 🚀 Bonus – Common Letters in Two Words
#
# **Problem:** Write a function `common_letters(w1, w2)` that returns a set of letters appearing in **both** words. Test with `"python"` and `"typhoon"`.
#
# **Expected output:** `{'p', 'y', 't', 'o', 'n'}` (order may vary)
#
# **💡 Hint:** `set(w1) & set(w2)` — a string is iterable, so `set("abc")` becomes `{'a','b','c'}`

# %%
# Bonus – Common Letters
def common_letters(w1, w2):
    pass  # your code here

print(common_letters("python", "typhoon"))
