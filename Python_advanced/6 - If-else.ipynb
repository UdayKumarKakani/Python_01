# %% [markdown]
# # Python if ... else Statement

# %% [markdown]
# The **if…elif…else** statement is used in Python for decision making.

# %% [markdown]
# # if statement syntax

# %% [markdown]
#     if test expression:
#
#         statement(s)

# %% [markdown]
# The program evaluates the test expression and will execute statement(s) only if the text expression is True.
#
# If the text expression is False, the statement(s) is not executed.

# %% [markdown]
# Python interprets non-zero values as True. None and 0 are interpreted as False.

# %% [markdown]
# # Example

# %%
num = 10

# try 0, -1 and None
if None:
    print("Number is positive")
print("This will print always")      #This print statement always print

#change number
# Out:
# This will print always

# %% [markdown]
# # if ... else Statement

# %% [markdown]
# # Syntax:

# %% [markdown]
#     if test expression:
#
#         Body of if
#
#     else:
#
#         Body of else

# %% [markdown]
# # Example

# %%
num = 10
if num > 0:
    print("Positive number")
else:
    print("Negative Number")
# Out:
# Positive number

# %% [markdown]
# # if...elif...else Statement

# %% [markdown]
# # Syntax:

# %% [markdown]
#     if test expression:
#
#         Body of if
#     elif test expression:
#
#         Body of elif
#     else:
#
#         Body of else

# %% [markdown]
# # Example:

# %%
num = 0

if num > 0:
    print("Positive number")
elif num == 0:
    print("ZERO")
else:
    print("Negative Number")
# Out:
# ZERO

# %% [markdown]
# # Nested if Statements

# %% [markdown]
# We can have a if...elif...else statement inside another if...elif...else statement. This is called nesting in computer programming.

# %% [markdown]
# # Example:

# %%
num = 10.5

if num >= 0:
    if num == 0:
        print("Zero")
    else:
        print("Positive number")
else:
    print("Negative Number")
# Out:
# Positive number

# %% [markdown]
# # Python program to find the largest element among three Numbers

# %%
num1 = 10
num2 = 50
num3 = 15

if (num1 >= num2) and (num1 >= num3):           #logical operator   and
    largest = num1
elif (num2 >= num1) and (num2 >= num3):
    largest = num2
else:
    largest = num3
print("Largest element among three numbers is: {}".format(largest))
# Out:
# Largest element among three numbers is: 50

# %% [markdown]
# ---
# ## Truthy and Falsy Values
#
# In Python, `if` checks for "truthiness," not just `True`/`False`. These values are **falsy**:
#
# | Falsy values | Truthy values |
# |--------------|---------------|
# | `False` | `True` |
# | `None` | any non-zero number |
# | `0`, `0.0` | any non-empty string `"hi"` |
# | `""` (empty string) | any non-empty list `[0]` |
# | `[]`, `{}`, `()` (empty containers) | any non-empty dict / tuple |
#
# ```python
# name = ""
# if name:
#     print("Got a name")
# else:
#     print("Empty!")    # prints this — "" is falsy
# ```

# %% [markdown]
# ---
# ## Ternary (Conditional) Expression
#
# A compact one-liner alternative to `if / else` when assigning a value:
#
# ```python
# # Long form
# if age >= 18:
#     status = "adult"
# else:
#     status = "minor"
#
# # Ternary form (same result)
# status = "adult" if age >= 18 else "minor"
# ```
#
# > **Use when:** the expression is short and easy to read. Don't nest ternaries — use a normal `if` block instead.

# %%
age = 20
status = "adult" if age >= 18 else "minor"
print(status)

# Mixing with logical operators
score = 75
result = "pass" if score >= 60 else "fail"
print(result)

# %% [markdown]
# ---
# # 📝 Assignments – If / Else
# ---

# %% [markdown]
# ## Task 1 – Grade Classifier
#
# **Problem:** Given `marks = 78`, print the grade:
# - 90+ → `A`
# - 80–89 → `B`
# - 70–79 → `C`
# - 60–69 → `D`
# - below 60 → `F`
#
# **Expected output:** `Grade: C`
#
# **💡 Hint:** Use `if / elif / else` chain (top-down comparisons)

# %%
# Task 1 – Grade Classifier
marks = 78

# %% [markdown]
# ## Task 2 – FizzBuzz (Single Number)
#
# **Problem:** Given `n`, print:
# - `"FizzBuzz"` if divisible by 3 **and** 5
# - `"Fizz"` if divisible by only 3
# - `"Buzz"` if divisible by only 5
# - the number itself otherwise
#
# Test with: 15, 9, 10, 7
#
# **Expected output:**
# ```
# FizzBuzz
# Fizz
# Buzz
# 7
# ```
#
# **💡 Hint:** Check the `and` condition first (most restrictive)

# %%
# Task 2 – FizzBuzz
for n in [15, 9, 10, 7]:
    pass  # write your if/elif/else here

# %% [markdown]
# ## Task 3 – Login Validator (Nested If)
#
# **Problem:** Given `username = "admin"` and `password = "1234"`:
# 1. First check if username equals `"admin"`
#    - If yes, check password
#      - If password equals `"1234"` → `"Login successful"`
#      - else → `"Wrong password"`
#    - else → `"User not found"`
#
# Test with: ("admin", "1234"), ("admin", "wrong"), ("guest", "1234")
#
# **Expected output:**
# ```
# Login successful
# Wrong password
# User not found
# ```
#
# **💡 Hint:** Nested `if` — the inner one only runs if the outer is true

# %%
# Task 3 – Login Validator
credentials = [("admin", "1234"), ("admin", "wrong"), ("guest", "1234")]
for username, password in credentials:
    pass  # nested if-else here

# %% [markdown]
# ## Task 4 – Triangle Type
#
# **Problem:** Given three side lengths `a, b, c`, determine the triangle type:
# - All three sides equal → `"Equilateral"`
# - Any two sides equal → `"Isosceles"`
# - All sides different → `"Scalene"`
#
# Test with: (5,5,5), (5,5,8), (3,4,5)
#
# **Expected output:**
# ```
# Equilateral
# Isosceles
# Scalene
# ```
#
# **💡 Hint:** Check `a == b == c` first, then `a == b or b == c or a == c`

# %%
# Task 4 – Triangle Type
triangles = [(5,5,5), (5,5,8), (3,4,5)]
for a, b, c in triangles:
    pass

# %% [markdown]
# ## 🚀 Bonus – Ticket Price Calculator
#
# **Problem:** Compute a movie ticket price based on age:
# - under 5 → `Free`
# - 5–17 → `$8` (child)
# - 18–59 → `$15` (adult)
# - 60+ → `$10` (senior)
#
# Use the **ternary** operator where possible, or `if/elif`.
# Test with ages: 3, 12, 30, 65
#
# **Expected output:**
# ```
# Age 3: Free
# Age 12: $8
# Age 30: $15
# Age 65: $10
# ```

# %%
# Bonus – Ticket Price
for age in [3, 12, 30, 65]:
    price = ""  # compute based on age
    print(f"Age {age}: {price}")
