# %% [markdown]
# # Python Functions

# %% [markdown]
# Function is a group of related statements that perform a specific task.

# %% [markdown]
# Functions help break our program into smaller and modular chunks. As our program grows larger and larger, functions make it more organized and manageable.
#
# It avoids repetition and makes code reusable.

# %% [markdown]
# # Syntax:

# %% [markdown]
#     def function_name(parameters):
#
#         """
#         Doc String
#         """
#
#         Statement(s)

# %% [markdown]
# 1. keyword "def" marks the start of function header
#
# 2. Parameters (arguments) through which we pass values to a function. These are optional
#
# 3. A colon(:) to mark the end of funciton header
#
# 4. Doc string describe what the function does. This is optional
#
# 5. "return" statement to return a value from the function. This is optional

# %% [markdown]
# # Example:

# %%
def print_name(name):
    """ 
    This function prints the name
    """
    print("Hello " + str(name))

# %% [markdown]
# # Function Call

# %% [markdown]
# Once we have defined a function, we can call it from anywhere

# %%
print_name('satish')
# Out:
# Hello satish

# %% [markdown]
# # Doc String

# %% [markdown]
# The first string after the function header is called the docstring and is short for documentation string.

# %% [markdown]
# Although optional, documentation is a good programming practice, always document your code

# %% [markdown]
# Doc string will be written in triple quotes so that docstring can extend up to multiple lines

# %%
print(print_name.__doc__) # print doc string of the function
# Out:
#
#     This function prints the name

# %% [markdown]
# # return Statement

# %% [markdown]
# The return statement is used to exit a function and go back to the place from where it was called.

# %% [markdown]
# Syntax:
#
#     return [expression]

# %% [markdown]
# -> return statement can contain an expression which gets evaluated and the value is returned.
#
# -> if there is no expression in the statement or the return statement itself is not present inside a function, then the function will return None Object

# %%
def get_sum(lst):
    """
    This function returns the sum of all the elements in a list
    """
    #initialize sum
    _sum = 0
    
    #iterating over the list
    for num in lst:
        _sum += num
    return _sum

# %%
s = get_sum([1, 2, 3, 4])
print(s)
# Out:
# 10

# %%
#print doc string
print(get_sum.__doc__)
# Out:
#     This function returns the sum of all the elements in a list

# %% [markdown]
# # How Function works in Python?

# %% [markdown]
# ![title](function_works.jpg)

# %% [markdown]
# # Scope and Life Time of Variables

# %% [markdown]
# -> Scope of a variable is the portion of a program where the variable is recognized

# %% [markdown]
# -> variables defined inside a function is not visible from outside. Hence, they have a local scope.

# %% [markdown]
# -> Lifetime of a variable is the period throughout which the variable exits in the memory.
#
# -> The lifetime of variables inside a function is as long as the function executes.

# %% [markdown]
# -> Variables are destroyed once we return from the function.

# %% [markdown]
# # Example:

# %%
global_var = "This is global variable"

def test_life_time():
    """
    This function test the life time of a variables
    """
    local_var = "This is local variable"
    print(local_var)       #print local variable local_var
    
    print(global_var)      #print global variable global_var
    
    

#calling function
test_life_time()

#print global variable global_var
print(global_var)

#print local variable local_var
print(local_var)
# Out:
# This is local variable
# This is global variable
# This is global variable
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-d5226680661e> in <module>()
#      19
#      20 #print local variable local_var
# ---> 21 print(local_var)
#
# NameError: name 'local_var' is not defined

# %% [markdown]
# # Python program to print Highest Common Factor (HCF) of two numbers

# %%
def computeHCF(a, b):
    """
    Computing HCF of two numbers
    """
    smaller = b if a > b else a  #consice way of writing if else statement
    
    hcf = 1
    for i in range(1, smaller+1):
        if (a % i == 0) and (b % i == 0):
            hcf = i
    return hcf

num1 = 6
num2 = 36

print("H.C.F of {0} and {1} is: {2}".format(num1, num2, computeHCF(num1, num2)))
# Out:
# H.C.F of 6 and 36 is: 6

# %% [markdown]
# ---
# ## Function Anatomy at a Glance
#
# | Part | Purpose | Required? |
# |------|---------|-----------|
# | `def` keyword | Marks start of function definition | Yes |
# | Function name | Identifier used to call the function | Yes |
# | Parameters `(...)` | Input values the function accepts | Optional |
# | Docstring `"""..."""` | Documents what the function does | Optional but recommended |
# | Body (indented) | Statements that run when called | Yes |
# | `return` | Sends a value back to the caller | Optional (defaults to `None`) |
#
# > If a function has no `return`, calling it returns `None` — not nothing.

# %% [markdown]
# ---
# ## Local vs Global Scope
#
# | Scope | Where defined | Where visible |
# |-------|--------------|---------------|
# | **Local** | Inside a function | Only within that function |
# | **Global** | At module (top) level | Everywhere in the module |
# | **`global` keyword** | Inside function (`global x`) | Lets you **modify** a global from inside a function |
#
# ```python
# counter = 0  # global
#
# def increment():
#     global counter   # tells Python to use the outer counter
#     counter += 1
# ```

# %% [markdown]
# ---
# # 📝 Assignments – Basics of Functions
# ---

# %% [markdown]
# ## Task 1 – Greet With Default
#
# **Problem:** Write a function `greet(name, greeting="Hello")` that prints `"<greeting>, <name>!"`.
#
# Call it once with just a name, once with both arguments.
#
# **Expected output:**
# ```
# Hello, Alice!
# Hi, Bob!
# ```
#
# **💡 Hint:** Default value goes in the function signature: `def greet(name, greeting="Hello"):`

# %%
# Task 1 – Greet With Default
def greet(name, greeting="Hello"):
    pass

greet("Alice")
greet("Bob", "Hi")

# %% [markdown]
# ## Task 2 – Sum and Average
#
# **Problem:** Write `stats(numbers)` that returns a **tuple** `(sum, average)` for a list of numbers.
#
# **Expected output:**
# ```
# (15, 3.0)
# ```
#
# **💡 Hint:** Use `sum(numbers)` and `len(numbers)`; return `(s, s/len(numbers))`

# %%
# Task 2 – Sum and Average
def stats(numbers):
    pass

print(stats([1, 2, 3, 4, 5]))

# %% [markdown]
# ## Task 3 – Is Even?
#
# **Problem:** Write `is_even(n)` that returns `True` if `n` is even, else `False`. Then loop over `[1, 2, 3, 4, 5]` and print each number with its result.
#
# **Expected output:**
# ```
# 1 -> False
# 2 -> True
# 3 -> False
# 4 -> True
# 5 -> False
# ```
#
# **💡 Hint:** A number is even when `n % 2 == 0`

# %%
# Task 3 – Is Even?
def is_even(n):
    pass

for x in [1, 2, 3, 4, 5]:
    print(f"{x} -> {is_even(x)}")

# %% [markdown]
# ## Task 4 – Scope Check
#
# **Problem:**
# 1. Define a global variable `total = 100`.
# 2. Write a function `add_bonus(x)` that uses the `global` keyword to add `x` to `total`.
# 3. Call `add_bonus(50)` and print `total`.
#
# **Expected output:** `150`
#
# **💡 Hint:** Inside the function: `global total; total += x`

# %%
# Task 4 – Scope Check
total = 100

def add_bonus(x):
    pass

add_bonus(50)
print(total)

# %% [markdown]
# ## 🚀 Bonus – Mini Temperature Converter
#
# **Problem:** Write two functions:
# - `c_to_f(c)` → returns Fahrenheit  (`c * 9/5 + 32`)
# - `f_to_c(f)` → returns Celsius  (`(f - 32) * 5/9`)
#
# Print both conversions for `c=100` and `f=32`.
#
# **Expected output:**
# ```
# 100C = 212.0F
# 32F = 0.0C
# ```

# %%
# Bonus – Temperature Converter
def c_to_f(c):
    pass

def f_to_c(f):
    pass

print(f"100C = {c_to_f(100)}F")
print(f"32F = {f_to_c(32)}C")
