# %% [markdown]
# # Operators

# %% [markdown]
# Operators are special symbols in Python that carry out arithmetic or logical computation. The value that the operator operates on is called the operand.

# %% [markdown]
# # Operator Types

# %% [markdown]
# 1. Arithmetic operators
#
# 2. Comparison (Relational) operators
#
# 3. Logical (Boolean) operators
#
# 4. Bitwise operators
#
# 5. Assignment operators
#
# 6. Special operators

# %% [markdown]
# # Arithmetic Operators

# %% [markdown]
# Arithmetic operators are used to perform mathematical operations like addition, subtraction, multiplication etc.

# %% [markdown]
#     + , -, *, /, %, //, **  are arithmetic operators

# %% [markdown]
# Example:

# %%
x, y = 10, 20

#addition
print(x + y)

#subtraction(-)

#multiplication(*)

#division(/)

#modulo division (%)

#Floor Division (//)

#Exponent (**)
# Out:
# 30

# %% [markdown]
# # Comparision Operators

# %% [markdown]
# Comparison operators are used to compare values. It either returns True or False according to the condition.

# %% [markdown]
#     >, <, ==, !=, >=, <= are comparision operators

# %%
a, b = 10, 20         

print(a < b)  #check a is less than b

#check a is greater than b

#check a is equal to b

#check a is not equal to b (!=)

#check a greater than or equal to b

#check a less than or equal to b
# Out:
# True

# %% [markdown]
# # Logical Operators

# %% [markdown]
# Logical operators are  **and, or, not** operators.

# %%
a, b = True, False

#print a and b
print(a and b)

#print a or b

#print not b
# Out:
# False

# %% [markdown]
# # Bitwise operators

# %% [markdown]
# Bitwise operators act on operands as if they were string of binary digits. It operates bit by bit

# %% [markdown]
#     &,  |,  ~,  ^,  >>,  << are Bitwise operators

# %%
a, b = 10, 4

#Bitwise AND
print(a & b)

#Bitwise OR


#Bitwise NOT


#Bitwise XOR


#Bitwise rightshift


#Bitwise Leftshift
# Out:
# 0

# %% [markdown]
# # Assignment operators

# %% [markdown]
# Assignment operators are used in Python to assign values to variables.
#
# a = 5 is a simple assignment operator that assigns the value 5 on the right to the variable a on the left.

# %% [markdown]
#     =,  +=,  -=,  *=,  /=,  %=,  //=,  **=, &=,  |=,  ^=,  >>=,  <<= are Assignment operators

# %%
a = 10

a += 10         #add AND
print(a)

#subtract AND (-=)

#Multiply AND (*=)

#Divide AND (/=)

#Modulus AND (%=)

#Floor Division (//=)

#Exponent AND (**=)
# Out:
# 20

# %% [markdown]
# # Special Operators

# %% [markdown]
# # Identity Operators

# %% [markdown]
# **is and is not** are the identity operators in Python.
#
# They are used to check if two values (or variables) are located on the same part of the memory.

# %%
a = 5
b = 5
print(a is b)    #5 is object created once both a and b points to same object

#check is not
# Out:
# True

# %%
l1 = [1, 2, 3]
l2 = [1, 2, 3]
print(l1 is l2)
# Out:
# False

# %%
s1 = "Rahul"
s2 = "Rahul"
print(s1 is not s2)
# Out:
# False

# %% [markdown]
# # MemberShip Operators

# %% [markdown]
# **in and not in** are the membership operators in Python.
#
# They are used to test whether a value or variable is found in a sequence (string, list, tuple, set and   dictionary).

# %%
lst = [1, 2, 3, 4]
print(1 in lst)       #check 1 is present in a given list or not

#check 5 is present in a given list
# Out:
# True

# %%
d = {1: "a", 2: "b"}
print(1 in d)
# Out:
# True

# %% [markdown]
# ---
# ## Operators Quick Reference
#
# | Category | Operators | Example |
# |----------|-----------|---------|
# | **Arithmetic** | `+  -  *  /  %  //  **` | `7 // 2` → `3` |
# | **Comparison** | `==  !=  >  <  >=  <=` | `5 == 5` → `True` |
# | **Logical** | `and  or  not` | `True and False` → `False` |
# | **Bitwise** | `&  \|  ^  ~  <<  >>` | `5 & 3` → `1` |
# | **Assignment** | `=  +=  -=  *=  /=  //=  **=` | `x += 2` |
# | **Identity** | `is  is not` | `a is b` |
# | **Membership** | `in  not in` | `3 in [1,2,3]` → `True` |
#
# > **Note:** `/` always returns a float (`10/2 = 5.0`). Use `//` for integer division.

# %% [markdown]
# ---
# ## Operator Precedence (Order of Evaluation)
#
# Python evaluates operators in a specific order — like math's PEMDAS, but extended:
#
# 1. `**` (exponent) — highest
# 2. `*  /  //  %`
# 3. `+  -`
# 4. `<  <=  >  >=  ==  !=`
# 5. `not`
# 6. `and`
# 7. `or` — lowest
#
# ```python
# result = 2 + 3 * 4      # 14, not 20
# result = (2 + 3) * 4    # 20 — parentheses override precedence
# result = True or False and False   # True (and binds tighter than or)
# ```
#
# > **Tip:** When in doubt, use parentheses for clarity — even when not strictly needed.

# %% [markdown]
# ---
# # 📝 Assignments – Operators
# ---

# %% [markdown]
# ## Task 1 – Mini Calculator
#
# **Problem:** Given `a = 17` and `b = 5`, print the result of all 7 arithmetic operators with labels.
#
# **Expected output:**
# ```
# Sum: 22
# Difference: 12
# Product: 85
# Division: 3.4
# Floor division: 3
# Modulus: 2
# Power: 1419857
# ```
#
# **💡 Hint:** Use `**` for power, `//` for floor division, `%` for remainder

# %%
# Task 1 – Mini Calculator
a, b = 17, 5

# %% [markdown]
# ## Task 2 – Even / Odd / Divisible
#
# **Problem:** Given `n = 24`:
# 1. Check if it is even (use `%`)
# 2. Check if it is divisible by both 3 **and** 4 (use `and`)
# 3. Check if it is divisible by 5 **or** 7 (use `or`)
#
# **Expected output:**
# ```
# Even: True
# Divisible by 3 and 4: True
# Divisible by 5 or 7: False
# ```
#
# **💡 Hint:** `n % 2 == 0` is the even check

# %%
# Task 2 – Even / Odd / Divisible
n = 24

# %% [markdown]
# ## Task 3 – Membership Check
#
# **Problem:** Given `vowels = "aeiou"` and `word = "python"`:
# - Loop through `word` and for each letter, print whether it `is a vowel` or `not a vowel` using `in`
#
# **Expected output:**
# ```
# p: not a vowel
# y: not a vowel
# t: not a vowel
# h: not a vowel
# o: vowel
# n: not a vowel
# ```
#
# **💡 Hint:** `if letter in vowels:` ... else ...

# %%
# Task 3 – Membership Check
vowels = "aeiou"
word = "python"

# %% [markdown]
# ## Task 4 – Compound Assignment Chain
#
# **Problem:** Start with `x = 10`. Apply the following in order and print `x` after each step:
# 1. `x += 5`
# 2. `x *= 2`
# 3. `x -= 4`
# 4. `x //= 3`
# 5. `x **= 2`
#
# **Expected output:**
# ```
# 15
# 30
# 26
# 8
# 64
# ```
#
# **💡 Hint:** Each operator modifies x in place — print after each line

# %%
# Task 4 – Compound Assignment Chain
x = 10

# %% [markdown]
# ## 🚀 Bonus – Leap Year Detector
#
# **Problem:** Write a one-line boolean expression to detect a leap year for `year`.
# A year is a leap year if:
# - divisible by 4 **AND not** divisible by 100, **OR**
# - divisible by 400
#
# Test with: 2000, 2020, 1900, 2023
#
# **Expected output:**
# ```
# 2000: True
# 2020: True
# 1900: False
# 2023: False
# ```
#
# **💡 Hint:** `(year % 4 == 0 and year % 100 != 0) or year % 400 == 0`

# %%
# Bonus – Leap Year
for year in [2000, 2020, 1900, 2023]:
    is_leap = False  # replace with your one-line expression
    print(f"{year}: {is_leap}")
