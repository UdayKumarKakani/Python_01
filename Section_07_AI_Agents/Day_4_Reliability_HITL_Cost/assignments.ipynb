# %% [markdown]
# # Day 4 — Assignments

# %% [markdown]
# ## Exercise 1 — Retry-only-transient
#
# Rewrite `with_retries` so it only retries on `httpx.HTTPError` / `httpx.TimeoutException`, and re-raises immediately on other exceptions. Add a small test that raises a `ValueError` and confirms it doesn't retry.

# %%
# your code here

# %% [markdown]
# ## Exercise 2 — Actually-blocking budget
#
# Give the responsible agent a `max_tokens=200` budget and ask it to summarize a long article. Confirm it returns `"stopped: budget (max_tokens)"` instead of finishing.

# %%
# your code here

# %% [markdown]
# ## Exercise 3 — Loop detector
#
# Track `(tool_name, args)` tuples across steps. If the same call happens 3 times in a run, halt and return `"stopped: repeating tool call"`. Test with a tool that always returns the same result.

# %%
# your code here

# %% [markdown]
# ## Stretch — Async job endpoint
#
# Wrap the responsible_agent in a FastAPI endpoint using `BackgroundTasks`. Start a job with `POST /agent`, poll `GET /agent/{job_id}` until it's `done`, and print the result.

# %%
# your code here
