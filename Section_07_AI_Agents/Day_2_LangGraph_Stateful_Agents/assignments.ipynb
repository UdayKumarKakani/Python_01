# %% [markdown]
# # Day 2 — Assignments

# %% [markdown]
# ## Exercise 1 — Add a fourth node
#
# Extend the class graph with a `translate` node that translates the final answer to Spanish. Wire it after `review`. Verify `steps_taken` shows all 4 steps.

# %%
# your code here

# %% [markdown]
# ## Exercise 2 — Retry on failure
#
# Modify `is_answer_ok` to reject any answer containing `"I don't know"`. On retry, feed the previous bad answer to `plan_node` (via a new state field) so it can improve. Test with a hard question.

# %%
# your code here

# %% [markdown]
# ## Exercise 3 — SqliteSaver checkpointing
#
# Swap `MemorySaver` for `SqliteSaver`. Run the graph, kill Python, restart it, load the checkpointer, and call `.get_state(config)` — confirm the state survived.

# %%
# your code here

# %% [markdown]
# ## Exercise 4 — create_react_agent
#
# Take yesterday's `calc` + `web_search` + `fetch_url` tools. Wrap each with `@tool`. Build with `create_react_agent`. Ask the same question you asked yesterday's hand-rolled agent. Compare code line counts.

# %%
# your code here

# %% [markdown]
# ## Stretch — Visualize the graph
#
# Call `graph.get_graph().draw_mermaid()` and print it. Paste the output into https://mermaid.live to see your workflow as a diagram. Commit the image to your notes.

# %%
# your code here
