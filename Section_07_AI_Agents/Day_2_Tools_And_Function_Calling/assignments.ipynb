# %% [markdown]
# # Day 2 — Assignments

# %% [markdown]
# ## Exercise 1 — Add a `get_time` tool
#
# Add a `get_time` tool that returns the current UTC time as a string. Give it a schema and register it. Ask *"What time is it?"* and verify the model calls the tool.

# %%
# your code here

# %% [markdown]
# ## Exercise 2 — Multi-tool question
#
# Ask a question that needs at least **two different tools** to answer, e.g. *"Search for the latest Python version, then calculate what 3.13 * 2 is."* Print the tool-call trace.

# %%
# your code here

# %% [markdown]
# ## Stretch — Description-quality experiment
#
# Rewrite the `web_search` description to be intentionally vague (e.g. `"searches"`). Rerun a few questions. Does the model still pick it correctly? Now rewrite it clearly with an example. Compare.

# %%
# your code here
