# %% [markdown]
# # Day 1 — Assignments

# %% [markdown]
# ## Exercise 1 — Add a new tool
#
# Add a `word_count[<text>]` tool that returns the number of words. Ask the agent: *"How many words are in the sentence 'The quick brown fox jumps over the lazy dog'?"* Verify it calls the tool instead of counting itself.

# %%
# your code here

# %% [markdown]
# ## Exercise 2 — Force a two-tool chain
#
# Ask a question that requires **both** `lookup` and `calc` (like the class demo). Print the full transcript. How many steps did it take?

# %%
# your code here

# %% [markdown]
# ## Stretch — Loop guardrail
#
# Add a safeguard: if the agent calls the **same tool with the same argument twice in a row**, break the loop and return `"stuck in a loop"`. Test it with a question the tools cannot answer.

# %%
# your code here
