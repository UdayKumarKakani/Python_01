# %% [markdown]
# # Day 3 — Assignments

# %% [markdown]
# ## Exercise 1 — Add a fourth node
#
# Extend the class graph with a `translate` node that translates the final answer to Spanish. Wire it after `review`. Verify the state history shows all 4 steps.

# %%
# your code here

# %% [markdown]
# ## Exercise 2 — Retry on failure
#
# Modify `is_answer_ok` to reject any answer containing the words `"I don't know"`. On retry, feed the previous bad answer to `plan_node` so it can improve. Test with a hard question.

# %%
# your code here

# %% [markdown]
# ## Stretch — Visualize the graph
#
# Call `graph.get_graph().draw_mermaid()` and print it. Paste the output into https://mermaid.live to see your workflow as a diagram.

# %%
# your code here
