# %% [markdown]
# # Day 3 — Assignments

# %% [markdown]
# ## Exercise 1 — Auto-remember facts
#
# Add an `extract_facts(text)` function: send the user's message to the LLM with the prompt *"If this message contains a persistent fact about the user (name, job, preferences), return it in ≤10 words. Otherwise return NONE."* Call `remember` when the result isn't NONE.

# %%
# your code here

# %% [markdown]
# ## Exercise 2 — Two users
#
# Create two `Chatbot` instances with different `user_id`s. Add different facts to each. Confirm that user A's memories never leak into user B's answers.

# %%
# your code here

# %% [markdown]
# ## Stretch — Session summary at logout
#
# Write a `close_session(bot)` method that summarizes the short-term memory into 3 bullets and saves them as long-term memories. Verify a fresh chatbot instance recalls them on the next session.

# %%
# your code here
