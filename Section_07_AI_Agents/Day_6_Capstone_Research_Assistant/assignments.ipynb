# %% [markdown]
# # Day 6 — Capstone Assignments

# %% [markdown]
# ## Exercise 1 — Run the capstone
#
# Start the server, fire a research job, poll until done, print the report. Verify `/research/memory` returns the report on a related query.

# %% [markdown]
# ## Exercise 2 — Break the budget
#
# Set `max_steps=2` in the graph. Fire a hard research question. Confirm the run stops early with a partial result — no exceptions leaked to the HTTP response.

# %% [markdown]
# ## Exercise 3 — Add a HITL step
#
# Before `save_node` runs, require a POST to `/research/{job_id}/approve`. The graph should pause after `synthesize_node` and resume only when the human approves.

# %% [markdown]
# ## Stretch — Section-wide demo
#
# Record a 90-second screen capture: `POST /research` → poll → show final report → search memory for a follow-up. That video is your Section 7 portfolio artifact.
