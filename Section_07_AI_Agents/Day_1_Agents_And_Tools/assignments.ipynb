# %% [markdown]
# # Day 1 — Assignments

# %% [markdown]
# ## Exercise 1 — Add a `get_time` tool
#
# Add a `get_time` tool that returns the current UTC time as a string. Register it in `TOOLS` and `TOOL_SCHEMAS`. Ask *"What time is it?"* and verify the model calls the tool.

# %%
# your code here

# %% [markdown]
# ## Exercise 2 — Multi-tool chain
#
# Ask a question that needs at least **two different tools** to answer — e.g. *"Search for the latest Python version, then calculate 3.13 * 2."* Print the full tool-call trace.

# %%
# your code here

# %% [markdown]
# ## Exercise 3 — Loop guardrail
#
# Add a safeguard: if the agent calls the **same tool with the same argument twice in a row**, break the loop and return `"stuck in a loop"`. Test with an intentionally unanswerable question.

# %%
# your code here

# %% [markdown]
# ## Stretch — Description-quality experiment
#
# Rewrite `web_search`'s description to be intentionally vague (e.g. just `"searches"`). Rerun 3 questions. Does the model still pick it correctly? Then rewrite it clearly with an example. Compare hit rate.

# %%
# your code here
