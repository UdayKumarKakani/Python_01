# %% [markdown]
# # Day 2 — Assignments

# %% [markdown]
# ## Exercise 1 — Movies in Chroma
#
# Take the 10 movie descriptions from Day 2. Load them into a Chroma collection with metadata `{"genre": ...}` for each (fantasy, action, animation, sci-fi, etc.). Query for `"space adventure"` and print the top 3 with genres.

# %%
# your code here

# %% [markdown]
# ## Exercise 2 — Filtered search
#
# Using the collection from Exercise 1, search for `"family friendly"` but restrict to `genre = "animation"`. Print results.

# %%
# your code here

# %% [markdown]
# ## Stretch — Persistent storage
#
# Rewrite Exercise 1 using `PersistentClient("./movie_db")`. Restart Python (or use a new notebook cell to open a fresh client) and confirm you can query the collection without re-adding the docs.

# %%
# your code here
