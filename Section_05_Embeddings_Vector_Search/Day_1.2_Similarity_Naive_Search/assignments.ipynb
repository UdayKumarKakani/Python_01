# %% [markdown]
# # Day 1.2 — Assignments
#
# Practice cosine similarity and naive search.

# %% [markdown]
# ## Exercise 1 — Similarity intuition
#
# Pick 4 short sentences: 2 about food, 2 about sports. Compute cosine similarity between every pair (6 pairs total). Which two are most similar? Least similar? Did the result match your intuition?

# %%
# your code here

# %% [markdown]
# ## Exercise 2 — Movie search engine
#
# Build a mini search engine over these 10 movie descriptions. Try 3 different queries and print the top-3 results for each.

# %%
movies = [
    "A boy discovers he is a wizard and attends a magical school.",
    "A thief who enters people's dreams to steal their secrets.",
    "Toys come to life when their owner is away.",
    "A shark terrorizes a small beach town.",
    "A lonely astronaut is stranded on Mars and must survive.",
    "Two hobbits journey to destroy a powerful ring.",
    "A retired assassin comes out of hiding to avenge his dog.",
    "A young lion prince runs away after his father is killed.",
    "A robot falls in love and tries to save humanity.",
    "A racecar dreams of winning the Piston Cup.",
]

# your search function and 3 queries here

# %% [markdown]
# ## Stretch — Measure the slowdown
#
# Time how long the naive search takes for `N = 10_000`, `100_000`, and `500_000` fake vectors. Plot the results (or just print them). Roughly how does the time scale with `N`?

# %%
# your code here
