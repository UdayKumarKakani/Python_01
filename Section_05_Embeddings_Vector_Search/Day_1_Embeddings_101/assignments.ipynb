# %% [markdown]
# # Day 1 — Assignments
#
# Do these in order. The first two are required. The stretch is optional.

# %% [markdown]
# ## Exercise 1 — Embed your own sentences
#
# Pick 5 sentences from your own life (a movie you liked, a food you had today, a project you're working on, etc.). Embed them with `all-MiniLM-L6-v2`. Print the shape of the vectors and the first 4 numbers of each.

# %%
# your code here

# %% [markdown]
# ## Exercise 2 — Model comparison
#
# Embed the sentence `"The quick brown fox jumps over the lazy dog."` with both `all-MiniLM-L6-v2` and `BAAI/bge-small-en-v1.5`. Print:
# - The dimension of each vector
# - The first 5 numbers of each
#
# Are the vectors identical? Why or why not?

# %%
# your code here

# %% [markdown]
# ## Stretch — Cost estimation
#
# Suppose you want to embed **50,000 customer support tickets**, average 100 tokens each. Using OpenAI's `text-embedding-3-small` at $0.02 per 1M tokens, how much would it cost? Show your math in a code cell.

# %%
# your calculation here
