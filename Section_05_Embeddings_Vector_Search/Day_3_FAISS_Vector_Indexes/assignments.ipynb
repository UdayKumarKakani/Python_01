# %% [markdown]
# # Day 3 — Assignments

# %% [markdown]
# ## Exercise 1 — Index your movie corpus
#
# Take the 10 movie descriptions from Day 2's assignment. Build a FAISS HNSW index and search for `"animated adventure"`. Print the top-3 results.

# %%
# your code here

# %% [markdown]
# ## Exercise 2 — Save, reload, re-query
#
# Save your movie index to `movies.faiss`. Load it back in a new variable. Confirm you can still search and get identical results.

# %%
# your code here

# %% [markdown]
# ## Stretch — Compare index types
#
# Build the same 10-movie corpus into both `IndexFlatIP` (exact) and `IndexHNSWFlat`. Run the same query on both. Are the top-3 results identical? Are the scores identical?

# %%
# your code here
