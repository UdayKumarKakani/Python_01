# %% [markdown]
# # Day 5 — Assignments

# %% [markdown]
# ## Exercise 1 — Chunk a Wikipedia article
#
# Copy any 3–4 paragraphs from a Wikipedia article into a Python string. Chunk it with your `recursive_chunk` function (chunk_size=300, overlap=30). Print the number of chunks and the first two chunks.

# %%
# your code here

# %% [markdown]
# ## Exercise 2 — Metadata-tagged Chroma
#
# Add your chunks from Exercise 1 to a Chroma collection with `source="wiki_article"` and `chunk_index=i` for each. Query for a phrase from the article and print the returned chunk with its `chunk_index`.

# %%
# your code here

# %% [markdown]
# ## Stretch — Tune the alpha
#
# Using the hybrid_search example from class, try `alpha=0.0`, `0.25`, `0.5`, `0.75`, `1.0` for the query `"ERR-4041"`. At what alpha does the exact match win? What happens at alpha=0?

# %%
# your code here
