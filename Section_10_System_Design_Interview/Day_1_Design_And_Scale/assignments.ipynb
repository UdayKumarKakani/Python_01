# %% [markdown]
# # Day 1 — Assignments (practice, mostly no code)

# %% [markdown]
# ## Exercise 1 — 30-minute whiteboard mock
#
# Pick your Section 6 or 7 capstone. Set a 30-minute timer. Whiteboard the design using the 5-step framework. Record yourself. Watch back — where did you skip clarifying / estimating?

# %% [markdown]
# ## Exercise 2 — Estimate numbers
#
# For a chatbot serving 100,000 DAU, each asking 3 questions, average 800 tokens per query, on openai/gpt-oss-20b (~$0.10 / 1M blended): compute daily cost, monthly cost, and vector storage for a 5-million-chunk KB (384-dim embeddings).

# %%
# your numbers here

# %% [markdown]
# ## Exercise 3 — Add a semantic cache to your Section 6 RAG
#
# Wrap your `/ask` with a Chroma-backed semantic cache (threshold ~0.15 distance). Measure the hit rate over 30 real queries.

# %%
# your code

# %% [markdown]
# ## Stretch — Design something you haven't built
#
# *"Design a Slack bot that summarizes long threads on demand."* Run the 5-step framework end-to-end. Write your architecture as a Markdown doc.
