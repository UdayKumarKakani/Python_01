# %% [markdown]
# # Day 2 — Assignments

# %% [markdown]
# ## Exercise 1 — Load 3 different formats
#
# Find or create three small files — one `.md`, one `.docx`, one `.pdf`. Load each with the appropriate loader and print the first 200 characters.

# %%
# your code here

# %% [markdown]
# ## Exercise 2 — Add a `.html` loader to the registry
#
# Write `load_html(path)` that reads an HTML file from disk and extracts clean text with `trafilatura`. Register it in `LOADERS` under `".html"`. Ingest an HTML file and verify chunks land in Chroma.

# %%
# your code here

# %% [markdown]
# ## Stretch — Ingest a Wikipedia article
#
# Use `load_url` to fetch any Wikipedia article. Ingest it into a Chroma collection. Ask a question about the topic and use the RAG pipeline from Day 1 to answer it.

# %%
# your code here
