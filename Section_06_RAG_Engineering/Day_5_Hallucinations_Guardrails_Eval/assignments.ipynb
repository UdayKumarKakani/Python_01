# %% [markdown]
# # Day 5 — Assignments

# %% [markdown]
# ## Exercise 1 — Refusal threshold
#
# Run your Day 1 RAG on 5 queries: 3 that have answers in the KB, 2 that don't. Print the top-1 distance for each. Pick a threshold that separates the two groups. Add a refusal branch to your RAG function.

# %%
# your code here

# %% [markdown]
# ## Exercise 2 — Injection detector
#
# Extend `looks_like_injection` with 3 more patterns you think are common. Test on 5 real-looking user questions and 5 injection attempts. What was your false-positive rate?

# %%
# your code here

# %% [markdown]
# ## Exercise 3 — Manual eval sheet
#
# Write 10 Q&A pairs for your KB. Save them as `eval.json`. Write a script that runs your RAG on all 10 and prints a per-row score. Save the scores back to the JSON with today's date so you can compare over time.

# %%
# your code here

# %% [markdown]
# ## Stretch — RAGAS faithfulness
#
# Install `ragas`, run its `faithfulness` metric on your 10-question dataset, and compare its scores to your manual ones. Where do they agree? Where do they disagree?

# %%
# your code here
