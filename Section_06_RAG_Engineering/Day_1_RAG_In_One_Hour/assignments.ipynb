# %% [markdown]
# # Day 1 — Assignments

# %% [markdown]
# ## Exercise 1 — Your own mini KB
#
# Replace the 6 AcmeCloud docs with 6 facts about **yourself** (favorite food, hometown, current project, etc.). Ask 3 questions and verify the RAG answers correctly.

# %%
# your code here

# %% [markdown]
# ## Exercise 2 — Break it on purpose
#
# Ask a question whose answer is **not** in your KB. Does the model say "I don't know", or does it hallucinate? If it hallucinates, tweak the prompt template until it refuses to answer.

# %%
# your code here

# %% [markdown]
# ## Stretch — top_k sweep
#
# Ask the same question with `top_k=1`, `top_k=3`, `top_k=6`. Does the answer change? Which top_k gives the cleanest answer for your KB?

# %%
# your code here
