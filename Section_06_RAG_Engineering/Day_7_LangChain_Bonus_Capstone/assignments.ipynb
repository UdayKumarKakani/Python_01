# %% [markdown]
# # Day 7 — Assignments

# %% [markdown]
# ## Exercise 1 — Run the LangChain capstone
#
# Start the app: `uvicorn main:app --reload`. Register a user, ingest 2 docs (one PDF + one URL), ask 3 questions. Verify the answers cite sources correctly.

# %% [markdown]
# ## Exercise 2 — Side-by-side diff
#
# Run `diff -u ../Day_6_Capstone_RAG_Chatbot/main.py main.py`. List 5 concrete differences. Which version do you find easier to read? Which would be easier to extend?

# %%
# your notes here

# %% [markdown]
# ## Exercise 3 — Swap the LLM
#
# Change `ChatTogether(...)` to `ChatOpenAI(model="gpt-4o-mini")` from `langchain_openai`. Confirm the whole `rag_chain` still works — the point of LangChain is that swapping providers is one line.

# %%
# your code

# %% [markdown]
# ## Exercise 4 — Add `MultiQueryRetriever`
#
# LangChain's `MultiQueryRetriever` uses the LLM to **rewrite one user query into 3-5 diverse queries**, retrieves for each, and unions the results. Wire it in between `vstore.as_retriever()` and the reranker. Ask a vague question ("is it safe?") and compare recall vs the base retriever.

# %%
# from langchain.retrievers.multi_query import MultiQueryRetriever
# your code

# %% [markdown]
# ## Stretch — LangSmith tracing
#
# Set `LANGSMITH_API_KEY` + `LANGSMITH_TRACING=true` in `.env`. Rerun a few queries. Open https://smith.langchain.com and screenshot the trace tree of your `rag_chain`. Compare to the Langfuse traces you set up in Section 9.
