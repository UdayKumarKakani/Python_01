# %% [markdown]
# # Day 3 — Assignments

# %% [markdown]
# ## Exercise 1 — Rerank on your own KB
#
# Take the KB from Day 1 (or Day 2 assignment). Query for a moderately vague question. Print the top-3 from **embedding-only search** and top-3 from **retrieve_and_rerank**. Did they differ?

# %%
# your code here

# %% [markdown]
# ## Exercise 2 — Expansion effect
#
# Pick a vague question like `"is it fast?"` or `"is it worth it?"`. Print the original, the expanded query, and the top-3 retrieved chunks for each. Which retrieval was better?

# %%
# your code here

# %% [markdown]
# ## Stretch — Cost check
#
# Reranking is nearly free. Query expansion costs an LLM call per query. Estimate the extra token cost if you serve 10,000 queries/day and each expansion uses ~80 tokens in + ~40 tokens out at the `Llama-3.3-70B-Instruct-Turbo` price.

# %%
# your calculation here
