# %% [markdown]
# # Day 4 — Assignments

# %% [markdown]
# ## Exercise 1 — Build your own prompt template
#
# Rewrite `build_prompt_v2` for a **legal-document assistant**. The system prompt should require the model to quote exact language when possible, and to always cite. Test on 3 fake legal chunks.

# %%
# your code here

# %% [markdown]
# ## Exercise 2 — Dedupe + cap
#
# Simulate a retrieval where 5 of 8 chunks are near-duplicates. Run through `dedupe` + `cap_tokens(max_tokens=300)`. Confirm the surviving chunks are unique and under budget.

# %%
# your code here

# %% [markdown]
# ## Stretch — Summarize-then-stuff
#
# Given 6 long retrieved chunks (~500 chars each), write a function that first summarizes each into 1–2 sentences using an LLM call, then stuffs the summaries into the RAG prompt. Compare answer quality vs stuffing the raw chunks.

# %%
# your code here
