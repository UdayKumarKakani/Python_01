# %% [markdown]
# # Day 2 — Assignments
# Colab-required for exercises 1 & 2.

# %% [markdown]
# ## Exercise 1 — Fine-tune on your Day 1 dataset
#
# Upload your Day 1 JSONL. Follow the class notebook and train 3 epochs. Test on 3 held-out inputs. Does the model do the right thing?

# %%
# your code (Colab)

# %% [markdown]
# ## Exercise 2 — Rank sweep
#
# Re-train with `r=4`, `r=16`, `r=64`. Which produces the best held-out predictions? Which is fastest?

# %%
# your code (Colab)

# %% [markdown]
# ## Stretch — Compare base vs fine-tuned
#
# Load the base model *without* the adapter. Run the same 3 test prompts through it. How verbose is the base compared to your fine-tune?

# %%
# your code (Colab)
