# %% [markdown]
# # Day 3 — Assignments (Colab-required)

# %% [markdown]
# ## Exercise 1 — Fine-tune on Dolly
#
# Reproduce the class notebook end-to-end. Note your final `train_loss` and `eval_loss`. Test 3 held-out prompts.

# %%
# your code (Colab)

# %% [markdown]
# ## Exercise 2 — Your own dataset
#
# Assemble 100+ chat-format examples for a real task you care about (data source: your notes, exported emails, forum posts, GitHub issues). Fine-tune. Compare 3 prompts before vs after.

# %%
# your code (Colab)

# %% [markdown]
# ## Stretch — Epoch sweep
#
# Train the same dataset for 1, 3, and 5 epochs. Plot the eval loss curves. At what epoch does eval loss start rising?

# %%
# your code (Colab)
