# %% [markdown]
# # Day 4 — Assignments

# %% [markdown]
# ## Exercise 1 — W&B for your Day 3 run
#
# Re-run yesterday's Dolly fine-tune with `report_to="wandb"`. Share the W&B run URL.

# %%
# your code (Colab)

# %% [markdown]
# ## Exercise 2 — Spot-check + accuracy
#
# Load 20 held-out examples. Print the model's output next to expected for each. Compute exact-match accuracy.

# %%
# your code (Colab)

# %% [markdown]
# ## Exercise 3 — LLM-as-judge
#
# Pick 10 free-form eval examples. Send them + expected + model output to a Together AI Llama call with the judge prompt from class. Aggregate scores.

# %%
# your code
