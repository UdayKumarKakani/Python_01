# %% [markdown]
# # Day 1 — Assignments

# %% [markdown]
# ## Exercise 1 — Design a dataset
#
# Pick a fine-tuning goal (e.g. "convert my emails into to-do lists", "answer as Yoda", "extract product names from tweets"). Write 10 chat-format examples. Save as JSONL.

# %%
# your code here

# %% [markdown]
# ## Exercise 2 — Split & count
#
# Load your JSONL from Exercise 1. Split 80/20. Print how many characters each set has total.

# %%
# your code here

# %% [markdown]
# ## Stretch — Diversity check
#
# Compute the average, min, and max input length in your dataset. If they cluster tightly, generate 3 more examples that intentionally stretch the range (very short + very long).

# %%
# your code here
