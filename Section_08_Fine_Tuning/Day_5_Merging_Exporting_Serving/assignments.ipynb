# %% [markdown]
# # Day 5 — Assignments

# %% [markdown]
# ## Exercise 1 — Merge + GGUF
#
# Take your Day 3 LoRA adapter. Merge it, export as `q4_k_m` GGUF. Report the final file size.

# %%
# your code (Colab)

# %% [markdown]
# ## Exercise 2 — Serve with Ollama
#
# Copy the `.gguf` to your laptop, install Ollama, register the model with a Modelfile, and chat with it. Paste one before/after example.

# %% [markdown]
# ## Exercise 3 — Push to HF Hub
#
# Push your merged model to a fresh HF repo. Share the URL.

# %%
# your code
