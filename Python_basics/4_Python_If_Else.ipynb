# %% [markdown]
# # Python Conditional Statement :  If ... Else Statement
#
# **Python Conditional Operators (conditions)  and If statements**
#
# Python supports the usual logical conditions from mathematics:
#
# **Equals: ** a == b
# **Not Equals: ** a != b
# **Less than:**  a < b
# **Less than or equal to:** a <= b
# **Greater than:** a > b
# **Greater than or equal to:** a >= b

# %% [markdown]
# ### If statement
#
# ---
#
#
# These conditions can be used in several ways, most commonly in "if statements" and loops.
#
# An "if statement" is written by using the if keyword.

# %%
a = 33

b = 200

if b>a:
  print("b is greater than a")
# Out:
# b is greater than a

# %% [markdown]
# **Indentation**
#
# Python relies on indentation, using whitespace, to define scope in the code. Other programming languages often use curly-brackets for this purpose.
#
# ---

# %%
#If statement, without indentation (will raise an error):

a = 33
b = 200
if b < a:
  print("b is greater than a") # you will get an error
  print("random text")

print("sample data")
# Out:
# sample data

# %% [markdown]
# **Elif**
#
# The elif keyword is pythons way of saying "if the previous conditions were not true, then try this condition".
#
# ---

# %%
a = 33

b = 33

if a > b:
  print("a is greater than b")
elif a == b:
  print("a is equal to b")

  #In this example a is equal to b, so the first condition is not true, but the elif condition is true, so we print to screen that "a and b are equal".
# Out:
# a is equal to b

# %% [markdown]
#  **Else**
#
# The else keyword catches anything which isn't caught by the preceding conditions.
#
# ---

# %%
a = 200

b = 30

if b > a:
  print("b is greater than a")

elif b == a:
  print("a is equal to b")

else:
  print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# You can also have an else without the elif:

# %%
a = 200
b = 33
if b > a:
  print("b is greater than a")
else:
  print("b is not greater than a")
# Out:
# b is not greater than a

# %% [markdown]
# **Short Hand If**
#
# If you have only one statement to execute, you can put it on the same line as the if statement.
#
# ---

# %%
if a > b: print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# **Short Hand If ... Else**
#
# If you have only one statement to execute, one for if, and one for else, you can put it all on the same line:
#
# ---

# %%
print("A") if a > b else print("B")
# Out:
# A

# %% [markdown]
# One line if else statement, with 3 conditions:

# %%
print("A") if a > b else print("=") if a == b else print("B")
# Out:
# A

# %% [markdown]
# **And**
#
# The and keyword is a **logical operator**, and is used to combine conditional statements:
#
# ---

# %%
a = 30
b = 40
c = 20

if b > a and b > c:
  print("both the conditions are true")
# Out:
# both the conditions are true

# %% [markdown]
# **Or**
#
# The or keyword is a **logical operator**, and is used to combine conditional statements:
#
# ---

# %%
a = 30
b = 40
c = 20

if b > a or b < c:
  print("Atleaset one condition is true")
# Out:
# Atleaset one condition is true

# %% [markdown]
# ---
# ## Nested If Statements
#
# You can place an `if` statement inside another `if` — this is called nesting, and it lets you check multiple conditions in layers:
#
# ```python
# num = 12
# if num > 0:
#     print("Positive number")
#     if num % 2 == 0:
#         print("and it's Even")
#     else:
#         print("and it's Odd")
# else:
#     print("Not a positive number")
# ```
#
# > **Tip:** Avoid deeply nested ifs (more than 2–3 levels) — they become hard to read. Combine conditions with `and`/`or` when possible.

# %%
num = 12
if num > 0:
    print("Positive number")
    if num % 2 == 0:
        print("and it's Even")
    else:
        print("and it's Odd")
else:
    print("Not a positive number")

# %% [markdown]
# ---
# ## Truthiness in Python
#
# In Python, every value has a **truthy** or **falsy** quality. You don't always need `== True`:
#
# **Falsy values** (treated as `False` in conditions):
# - `0` (zero)
# - `""` (empty string)
# - `[]` (empty list)
# - `{}` (empty dict/set)
# - `None`
# - `False`
#
# **Everything else is truthy.**
#
# ```python
# name = ""
# if name:                   # same as: if name != ""
#     print("Name provided")
# else:
#     print("No name given")
# ```

# %%
# Falsy values
for val in [0, "", [], {}, None, False]:
    if val:
        print(f"{repr(val):10} → Truthy")
    else:
        print(f"{repr(val):10} → Falsy")

print()
# Practical use
name = ""
if name:
    print(f"Hello, {name}!")
else:
    print("Please enter your name.")

# %% [markdown]
# ---
# # 📝 Assignments – If / Elif / Else
# ---

# %% [markdown]
# ## Task 1 – Grade Calculator
#
# **Problem:** Given `marks = 72`, print the grade:
# - 90–100 → `"A"`
# - 80–89 → `"B"`
# - 70–79 → `"C"`
# - 60–69 → `"D"`
# - below 60 → `"F"`
#
# **Expected output:** `Grade: C`
#
# **💡 Hint:** Use `if/elif/elif/elif/else` chain. Check from highest range downward.

# %%
# Task 1 – Grade Calculator
marks = 72

# %% [markdown]
# ## Task 2 – Even or Odd
#
# **Problem:** `number = 47` — print whether it is `"Even"` or `"Odd"`.
#
# **Expected output:** `47 is Odd`
#
# **💡 Hint:** `number % 2 == 0` is True for even numbers

# %%
# Task 2 – Even or Odd
number = 47

# %% [markdown]
# ## Task 3 – Leap Year Checker
#
# **Problem:** `year = 2024` — is it a leap year?
#
# A year is a leap year if:
# - Divisible by 4 **AND** (not divisible by 100 **OR** divisible by 400)
#
# **Expected output:** `2024 is a Leap Year`
#
# **💡 Hint:** `year % 4 == 0 and (year % 100 != 0 or year % 400 == 0)`

# %%
# Task 3 – Leap Year
year = 2024

# %% [markdown]
# ## Task 4 – Ticket Pricing
#
# **Problem:** `age = 15` — print the ticket price:
# - Under 5 → Free
# - 5–12 → ₹50
# - 13–17 → ₹100
# - 18+ → ₹200
#
# **Expected output:** `Ticket price: ₹100`
#
# **💡 Hint:** Use `if/elif/elif/else` with `age < 5`, `age <= 12`, `age <= 17`

# %%
# Task 4 – Ticket Pricing
age = 15

# %% [markdown]
# ## Task 5 – Ternary Expression
#
# **Problem:** `temperature = 38` — use a **one-line** ternary expression to print `"Hot"` if temp > 35, else `"Comfortable"`.
#
# **Expected output:** `Hot`
#
# **💡 Hint:** `print("Hot") if temperature > 35 else print("Comfortable")`

# %%
# Task 5 – Ternary
temperature = 38

# %% [markdown]
# ## 🚀 Bonus – FizzBuzz
#
# **Problem:** For numbers 1 to 20, print:
# - `"FizzBuzz"` if divisible by both 3 and 5
# - `"Fizz"` if divisible by only 3
# - `"Buzz"` if divisible by only 5
# - The number itself otherwise
#
# **Expected output (first few):** `1, 2, Fizz, 4, Buzz, Fizz, 7, 8, Fizz, Buzz, 11, Fizz, 13, 14, FizzBuzz...`
#
# **💡 Hint:** Check `% 15 == 0` (divisible by both 3 and 5) **first** — most specific condition goes first

# %%
# Bonus – FizzBuzz (1 to 20)
for n in range(1, 21):
    pass  # replace pass with your conditions
