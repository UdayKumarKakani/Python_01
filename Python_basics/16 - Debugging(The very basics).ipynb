# %% [markdown]
# # Debugging

# %% [markdown]
# **pdb** implements an interactive debugging environment for Python programs. It includes features to let you pause your program, look at the values of variables, and watch program execution step-by-step, so you can understand what your program actually does and find bugs in the logic.

# %% [markdown]
# # Starting the Debugger

# %% [markdown]
# **From the Command Line**

# %%
def seq(n):
    for i in range(n):
        print(i)
    return

seq(5)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# **From Within Your Program**

# %%
import pdb

#interactive debugging
def seq(n):
    for i in range(n):
        breakpoint()
        pdb.set_trace() # breakpoint
        print(i)
    return

seq(5)


# c : continue
# q: quit
# h: help
# list
# p: print
# p locals()
# p globals()
# Out:
# > /tmp/ipython-input-3-4223984721.py(6)seq()
#       4         breakpoint()
#       5
# ----> 6         print(i)
#       7     return
#       8
#
# ipdb> c
# 0
# > /tmp/ipython-input-3-4223984721.py(6)seq()
#       4         breakpoint()
#       5
# ----> 6         print(i)
#       7     return
#       8
#
# ipdb> c
# 1
# > /tmp/ipython-input-3-4223984721.py(6)seq()
#       4         breakpoint()
#       5
# ----> 6         print(i)
#       7     return
#       8
#
# ipdb> p
# *** SyntaxError: invalid syntax
# ipdb> print
# <built-in function print>
# ipdb> locals()
# {'n': 5, 'i': 2}
# ipdb> globals()
# ...

# %% [markdown]
# # Debugger Commands

# %% [markdown]
# **1. h(elp) [command]**

# %% [markdown]
# Without argument, print the list of available commands. With a command as argument, print help about that command. help pdb displays the full documentation (the docstring of the pdb module). Since the command argument must be an identifier, help exec must be entered to get help on the ! command.

# %% [markdown]
# **2. w(here)**
#
# Print a stack trace, with the most recent frame at the bottom. An arrow indicates the current frame, which determines the context of most commands.

# %% [markdown]
# **3. d(own) [count]**
#
# Move the current frame count (default one) levels down in the stack trace (to a newer frame).

# %% [markdown]
# **4.c(ont(inue))**
#
# Continue execution, only stop when a breakpoint is encountered.

# %% [markdown]
# **5. q(uit)**
#
# Quit from the debugger. The program being executed is aborted.

# %% [markdown]
# **Termial/Command prompt based debugging**

# %% [markdown]
# ---
# ## pdb Command Cheat Sheet
#
# | Command | Shortcut | What it does |
# |---------|----------|--------------|
# | `help` | `h` | List all commands or help for one |
# | `list` | `l` | Show source code around current line |
# | `next` | `n` | Run next line (don't step into functions) |
# | `step` | `s` | Step **into** the next function call |
# | `continue` | `c` | Run until next breakpoint |
# | `return` | `r` | Run until current function returns |
# | `print <expr>` | `p` | Print value of an expression |
# | `pp <expr>` | – | Pretty-print value |
# | `where` | `w` | Show call stack (current frame at bottom) |
# | `up` / `down` | `u` / `d` | Move up/down the call stack |
# | `quit` | `q` | Exit debugger and abort program |
# | `break N` | `b N` | Set breakpoint at line N |
# | `!stmt` | – | Execute arbitrary Python in current frame |

# %% [markdown]
# ---
# ## Other Debugging Techniques
#
# Besides `pdb`, you can use these lighter techniques:
#
# ### 1. `print()` Debugging — fast & simple
# ```python
# print(f"DEBUG: x={x}, type={type(x)}")
# ```
#
# ### 2. `assert` — fail-fast invariants
# ```python
# def average(nums):
#     assert len(nums) > 0, "List cannot be empty"
#     return sum(nums) / len(nums)
# ```
# If the condition is False, raises `AssertionError` with your message.
#
# ### 3. The `logging` module — production-grade
# ```python
# import logging
# logging.basicConfig(level=logging.DEBUG)
# logging.debug("Value of x = %s", x)
# logging.warning("Disk almost full")
# ```
#
# ### 4. `breakpoint()` — Python 3.7+
# Drops you into pdb at exactly that line. Cleaner than `import pdb; pdb.set_trace()`.

# %% [markdown]
# ---
# # 📝 Assignments – Debugging
# ---

# %% [markdown]
# ## Task 1 – Find the Bug with `print`
#
# **Problem:** The function below is supposed to return the average of a list, but returns the wrong value. Add `print()` statements to find the bug, then fix it.
#
# ```python
# def buggy_average(nums):
#     total = 0
#     for n in nums:
#         total += n
#     return total / (len(nums) + 1)   # bug here!
#
# print(buggy_average([10, 20, 30]))  # should print 20.0, but prints 15.0
# ```
#
# **Expected (fixed) output:** `20.0`
#
# **💡 Hint:** Print `total`, `len(nums)` before the `return` and see what's off-by-one

# %%
# Task 1 – Debug with print
def buggy_average(nums):
    total = 0
    for n in nums:
        total += n
    return total / (len(nums) + 1)   # fix this

print(buggy_average([10, 20, 30]))

# %% [markdown]
# ## Task 2 – Use `assert` for Validation
#
# **Problem:** Write `divide(a, b)` that uses `assert` to ensure `b != 0`, then returns `a / b`. Test it with `(10, 2)` and `(10, 0)`. Wrap the bad call in `try / except AssertionError`.
#
# **Expected output:**
# ```
# 5.0
# AssertionError: b must not be zero
# ```
#
# **💡 Hint:** `assert b != 0, "b must not be zero"`

# %%
# Task 2 – assert validation
def divide(a, b):
    pass

print(divide(10, 2))
try:
    print(divide(10, 0))
except AssertionError as e:
    print(f"AssertionError: {e}")

# %% [markdown]
# ## Task 3 – Set a Breakpoint
#
# **Problem:** Use `breakpoint()` inside the loop below to inspect `total` and `i` partway through. Run it, type `p total`, `p i`, then `c` to continue. Comment out the `breakpoint()` line before submitting.
#
# ```python
# def running_sum(nums):
#     total = 0
#     for i, n in enumerate(nums):
#         # breakpoint()   <-- uncomment to inspect
#         total += n
#     return total
#
# print(running_sum([1, 2, 3, 4, 5]))
# ```
#
# **Expected output:** `15`
#
# **💡 Hint:** Inside pdb: `p total` shows current sum, `n` runs next line, `c` continues

# %%
# Task 3 – breakpoint()
def running_sum(nums):
    total = 0
    for i, n in enumerate(nums):
        # breakpoint()   # uncomment to inspect
        total += n
    return total

print(running_sum([1, 2, 3, 4, 5]))

# %% [markdown]
# ## Task 4 – Use the `logging` Module
#
# **Problem:** Use the `logging` module (level `DEBUG`) to log:
# - `INFO` when a function starts
# - `DEBUG` for each intermediate value
# - `WARNING` if input is empty
#
# Apply it to `compute_sum(nums)` which returns the sum of `nums`.
#
# **Expected output (example):**
# ```
# INFO:root:compute_sum called with [1, 2, 3]
# DEBUG:root:total so far: 1
# DEBUG:root:total so far: 3
# DEBUG:root:total so far: 6
# 6
# ```
#
# **💡 Hint:** `logging.basicConfig(level=logging.DEBUG)`, then `logging.info()`, `logging.debug()`, `logging.warning()`

# %%
# Task 4 – logging
import logging
logging.basicConfig(level=logging.DEBUG)

def compute_sum(nums):
    pass

print(compute_sum([1, 2, 3]))

# %% [markdown]
# ## 🚀 Bonus – Hunt the Bug
#
# **Problem:** The function below is supposed to return the **maximum** element of a list, but has a bug. Use any debugging tool (print / breakpoint / asserts) to locate and **fix** the bug.
#
# ```python
# def find_max(nums):
#     max_val = 0                  # bug: assumes all values are positive
#     for n in nums:
#         if n > max_val:
#             max_val = n
#     return max_val
#
# print(find_max([-5, -2, -10, -8]))   # should print -2, but prints 0
# ```
#
# **Expected (fixed) output:** `-2`
#
# **💡 Hint:** Initialize `max_val` from the list itself: `max_val = nums[0]`

# %%
# Bonus – Hunt the Bug
def find_max(nums):
    max_val = 0   # fix this
    for n in nums:
        if n > max_val:
            max_val = n
    return max_val

print(find_max([-5, -2, -10, -8]))
