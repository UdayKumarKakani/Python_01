# %% [markdown]
# #Tuples
#
# **A tuple is a collection which is ordered and immutable (unchangeable). In Python tuples are written with round brackets.**
#
#
# ---

# %%
abc = ("apple","banana",1,1.2,[5,6])
b = [1,2,[3,4]]
print(abc)
print(b)
# Out:
# ('apple', 'banana', 1, 1.2, [5, 6])
# [1, 2, [3, 4]]

# %% [markdown]
# **Access Tuple Items**
#
# You can access tuple items by referring to the index number, inside square brackets: (indexing start from 0 to n-1)
#
# ---

# %%
thistuple = ("apple","banana","cherry")
print(thistuple[1])
# Out:
# banana

# %% [markdown]
# **Change Tuple Values**
#
# Once a tuple is created, you cannot change its values. **Tuples are unchangeable**.
#
# ---

# %%
thistuple = ("apple","banana","cherry")
thistuple[1]="blackcurrat"
print(thistuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4-3250847885.py in <cell line: 0>()
#       1 thistuple = ("apple","banana","cherry")
# ----> 2 thistuple[1]="blackcurrat"
#       3 print(thistuple)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# **Loop Through a Tuple**
#
# You can loop through the tuple items by using a **for loop**.
#
# ---

# %%
thistuple = ("apple","banana","cherry")
for x in thistuple:
  print(x)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# **Check if Item Exists**
#
# To determine if a specified item is present in a tuple use the **in keyword**:
#
# ---

# %%
thistuple = ("apple","banana","cherry")
if "bananaa" in thistuple:
  print("Yes, Banana in this tuple")

# %% [markdown]
# **Tuple Length**
#
# To determine how many items a tuple has, use the **len() method**:
#
# ---

# %%
thistuple = ("apple","banana","cherry")
print(len(thistuple))
# Out:
# 3

# %% [markdown]
# **Add Items**
#
# Once a tuple is created, you cannot add items to it. **Tuples are unchangeable.**
#
# ---

# %%
thistuple = ("apple", "banana", "cherry")
thistuple[3] = "orange" # This will raise an error
print(thistuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-9-4110533726.py in <cell line: 0>()
#       1 thistuple = ("apple", "banana", "cherry")
# ----> 2 thistuple[3] = "orange" # This will raise an error
#       3 print(thistuple)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# **Remove Items**
#
# Note: You cannot remove items in a tuple.Tuples are unchangeable, so you cannot remove items from it, but you can delete the tuple completely:
#
# ---

# %%
thistuple = ("apple", "banana", "cherry")
del thistuple
print(thistuple) #this will raise an error because the tuple no longer exists
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-10-1828026926.py in <cell line: 0>()
#       1 thistuple = ("apple", "banana", "cherry")
#       2 del thistuple
# ----> 3 print(thistuple) #this will raise an error because the tuple no longer exists
#
# NameError: name 'thistuple' is not defined

# %% [markdown]
# **The tuple() Constructor**
#
# It is also possible to use the tuple() constructor to make a tuple.
#
# ---

# %%
thistuple = tuple(("apple","banana","cherry"))
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %% [markdown]
# **Tuple Methods**
#
# Python has two built-in methods that you can use on tuples.
#
# **count():** Returns the number of times a specified value occurs in a tuple
#
# **index()	:** Searches the tuple for a specified value and returns the position of where it was found

# %%
thistuple = (1, 3, 7, 8, 7, 7, 5, 4, 6, 8, 5)

x = thistuple.count(5)

print(x)
# Out:
# 2

# %%
thistuple = (1, 3, 7, 8, 7, 5, 4, 6, 8, 5)

x = thistuple.index(3)

print(x)
# Out:
# 1

# %% [markdown]
# ---
# ## Tuple Unpacking
#
# Tuple unpacking lets you assign multiple variables at once from a tuple — one of Python's most elegant features:
#
# ```python
# point = (10, 20)
# x, y = point           # unpack into x and y
# print(x)  # 10
# print(y)  # 20
# ```
#
# **Swapping variables** is easy with unpacking:
# ```python
# a, b = 5, 10
# a, b = b, a    # swap in one line!
# print(a, b)    # 10 5
# ```

# %%
# Tuple unpacking
point = (10, 20)
x, y = point
print(f"X={x}, Y={y}")

# Swap variables using tuple unpacking
a, b = 5, 10
print(f"Before swap: a={a}, b={b}")
a, b = b, a
print(f"After swap:  a={a}, b={b}")

# Unpack a 3-element tuple
name, age, city = ("Alice", 22, "Delhi")
print(f"{name} is {age} from {city}")

# %% [markdown]
# ---
# ## When to Use Tuples vs Lists
#
# | | **Tuple** | **List** |
# |---|---|---|
# | Syntax | `(1, 2, 3)` | `[1, 2, 3]` |
# | Mutable? | ❌ No (immutable) | ✅ Yes |
# | Use when | Data shouldn't change | Data needs to be modified |
# | Examples | Coordinates `(lat, lon)`, RGB colors `(255,0,0)`, DB rows | Shopping cart, student list |
# | Speed | Slightly faster | Slightly slower |
# | As dict key? | ✅ Yes | ❌ No |
#
# > **Rule of thumb:** If your data is fixed and shouldn't change, use a tuple. If it needs to grow, shrink, or be modified, use a list.

# %% [markdown]
# ---
# # 📝 Assignments – Tuples
# ---

# %% [markdown]
# ## Task 1 – Create and Access
#
# **Problem:** Create a tuple `student = ("Alice", 20, "Computer Science", 8.5)`
# (name, age, department, GPA)
#
# Print:
# 1. The student's name
# 2. The GPA
# 3. The total number of fields in the tuple
#
# **Expected output:**
# ```
# Name: Alice
# GPA: 8.5
# Fields: 4
# ```
#
# **💡 Hint:** Access using index — `student[0]` for name, `student[3]` for GPA; `len(student)` for total

# %%
# Task 1 – Create and Access
student = ("Alice", 20, "Computer Science", 8.5)

# %% [markdown]
# ## Task 2 – Tuple Unpacking
#
# **Problem:** Unpack coordinates and print them clearly.
#
# ```python
# coordinates = (28.6139, 77.2090)  # Delhi's latitude and longitude
# ```
#
# **Expected output:**
# ```
# Latitude: 28.6139
# Longitude: 77.209
# ```
#
# **💡 Hint:** `lat, lon = coordinates` — Python unpacks the tuple into two variables

# %%
# Task 2 – Tuple Unpacking
coordinates = (28.6139, 77.2090)

# %% [markdown]
# ## Task 3 – Immutability Workaround
#
# **Problem:** You have `colors = ("red", "green", "blue")`.
# Change `"green"` to `"yellow"` — but tuples are immutable!
#
# **Workaround:** Convert to list → modify → convert back to tuple.
#
# **Expected output:**
# ```
# Original: ('red', 'green', 'blue')
# Modified: ('red', 'yellow', 'blue')
# ```
#
# **💡 Hints:**
# - `list(my_tuple)` converts tuple → list
# - `my_list[1] = "yellow"` changes the second item
# - `tuple(my_list)` converts list → tuple

# %%
# Task 3 – Immutability Workaround
colors = ("red", "green", "blue")

# %% [markdown]
# ## Task 4 – Count and Index
#
# **Problem:** `numbers = (1, 4, 2, 4, 7, 4, 9, 4)`
# 1. How many times does `4` appear?
# 2. At what index does `7` first appear?
#
# **Expected output:**
# ```
# 4 appears 4 times
# 7 is at index 4
# ```
#
# **💡 Hint:** `.count(value)` counts occurrences; `.index(value)` returns the first position

# %%
# Task 4 – Count and Index
numbers = (1, 4, 2, 4, 7, 4, 9, 4)

# %% [markdown]
# ## 🚀 Bonus – Cities with Position
#
# **Problem:** Create a tuple of 5 Indian cities. Print each city with its position number (1-based).
#
# **Expected output:**
# ```
# 1. Mumbai
# 2. Delhi
# 3. Bangalore
# 4. Chennai
# 5. Kolkata
# ```
#
# **💡 Hint:** `for i, city in enumerate(cities, 1):` — the `1` makes it start counting from 1

# %%
# Bonus – Cities with position
cities = ("Mumbai", "Delhi", "Bangalore", "Chennai", "Kolkata")
