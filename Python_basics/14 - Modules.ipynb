# %% [markdown]
# # Modules

# %% [markdown]
# Modules refer to a file containing Python statements and definitions.
#
# A file containing Python code, for e.g.: abc.py, is called a module and its module name would be "abc".

# %% [markdown]
# We use modules to break down large programs into small manageable and organized files. Furthermore, modules provide reusability of code.
#
# We can define our most used functions in a module and import it, instead of copying their definitions into different programs.

# %% [markdown]
# # How to import a module?

# %% [markdown]
# We use the import keyword to do this.

# %%
import math #imported example module

# %% [markdown]
# Using the module name we can access the function using dot (.) operation.

# %%
print(f"Square root of 25: {math.sqrt(25)}")
# Out:
# Square root of 25: 5.0

# %% [markdown]
# Python has a lot of standard modules available.
#
# https://docs.python.org/3/py-modindex.html

# %% [markdown]
# # Examples:

# %% [markdown]
# os Module: Interacting with the Operating System. The os module provides functions for interacting with the operating system, like creating directories (os.mkdir()), listing directory contents (os.listdir()), getting the current working directory (os.getcwd()), and manipulating file paths (os.path.join()).
#
# sys Module: System-Specific Parameters and Functions. The sys module gives you access to variables and functions that interact with the Python interpreter, allowing you to fine-tune scripts and applications with Python's runtime environment. You can use it to access command-line arguments (sys.argv), exit the program (sys.exit()), check the Python version (sys.version), and manage the module search path (sys.path).
#
# math Module: Mathematical Operations. The math module provides functions for various mathematical operations, such as square roots (math.sqrt()), trigonometric functions (math.sin(), math.cos()), and constants like pi (math.pi).
#
# datetime Module: Managing Dates and Times. The datetime module offers classes for manipulating dates and times, including retrieving the current date and time (datetime.datetime.now()), performing date arithmetic, and formatting dates into strings (strftime()).
#
# random Module: Generating Random Data. The random module provides functions for generating pseudo-random numbers and selecting random elements from sequences. This is useful for simulations, games, and testing scenarios. You can generate random floats (random.random()), random integers within a range (random.randint()), and randomly select items from a list (random.choice()).
#
# json Module: Working with JSON Data. The json module is invaluable for handling JSON (JavaScript Object Notation) data, a common format for exchanging data between web applications and servers. It allows for serialization (converting Python objects to JSON strings or files) and deserialization (parsing JSON strings or files into Python objects). You can parse JSON data from a string using json.loads() and convert Python objects to JSON strings using json.dumps()
#
# csv Module: Working with CSV Files. The csv module provides tools for reading and writing data in the Comma Separated Values format, which is common for tabular data.
#
# string Module: String Constants and Utilities. The string module provides constants like string.ascii_letters (for all uppercase and lowercase ASCII letters) and utility functions for string manipulation

# %%
import sys
sys.version_info
# Out:
# sys.version_info(major=3, minor=11, micro=15, releaselevel='final', serial=0)

# %%
import os
print(os.getenv("ANTHROPIC_API_KEY"))
# Out:
# None

# %%
import math
print(math.pi)
# Out:
# 3.141592653589793

# %%
import datetime
datetime.datetime.today()
# Out:
# datetime.datetime(2026, 7, 6, 20, 45, 24, 650918)

# %% [markdown]
# # import with renaming

# %%
import math as m
print(m.pi)
# Out:
# 3.141592653589793

# %% [markdown]
# # from...import statement

# %% [markdown]
# We can import specific names form a module without importing the module as a whole.

# %%
from datetime import datetime
datetime.now()
# Out:
# datetime.datetime(2026, 6, 29, 8, 1, 16, 69748)

# %% [markdown]
# # import all names

# %%
from math import *
print("Value of PI is " + str(pi))
# Out:
# Value of PI is 3.141592653589793

# %% [markdown]
# # dir() built in function

# %% [markdown]
# We can use the dir() function to find out names that are defined inside a module.

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
import string
string.ascii_letters
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %% [markdown]
# ---
# ## Common Built-in Modules Reference
#
# | Module | Use Case | Example |
# |--------|----------|---------|
# | `math` | Math operations | `math.sqrt(16)` → `4.0` |
# | `random` | Random numbers | `random.randint(1, 10)` |
# | `datetime` | Dates & times | `datetime.now()` |
# | `os` | OS interaction | `os.getcwd()` |
# | `sys` | Interpreter info | `sys.version` |
# | `json` | JSON parsing | `json.dumps(data)` |
# | `string` | String constants | `string.ascii_lowercase` |
# | `statistics` | Stats functions | `statistics.mean([1,2,3])` |

# %% [markdown]
# ---
# ## Import Styles Cheat Sheet
#
# | Syntax | Effect |
# |--------|--------|
# | `import math` | Use as `math.sqrt(9)` |
# | `import math as m` | Alias — use as `m.sqrt(9)` |
# | `from math import sqrt` | Use `sqrt(9)` directly |
# | `from math import sqrt as s` | Alias single name |
# | `from math import *` | Imports **all** names (avoid — pollutes namespace) |
#
# > **Tip:** Use `dir(module)` to list what's inside, and `help(module.function)` to read docs.

# %% [markdown]
# ---
# # 📝 Assignments – Modules
# ---

# %% [markdown]
# ## Task 1 – Math Toolkit
#
# **Problem:** Using the `math` module, compute and print:
# 1. Square root of 144
# 2. The value of pi rounded to 4 decimals
# 3. The factorial of 6
#
# **Expected output:**
# ```
# 12.0
# 3.1416
# 720
# ```
#
# **💡 Hint:** `math.sqrt()`, `round(math.pi, 4)`, `math.factorial()`

# %%
# Task 1 – Math Toolkit
import math

# %% [markdown]
# ## Task 2 – Random Dice Roller
#
# **Problem:** Use the `random` module to simulate rolling a 6-sided die 5 times. Print each roll.
#
# **Expected output (example):**
# ```
# Roll 1: 4
# Roll 2: 2
# Roll 3: 6
# Roll 4: 1
# Roll 5: 5
# ```
#
# **💡 Hint:** `random.randint(1, 6)` inside a `for i in range(1, 6):` loop

# %%
# Task 2 – Random Dice Roller
import random

# %% [markdown]
# ## Task 3 – Today's Date
#
# **Problem:** Using `datetime`, print:
# 1. Today's date in `YYYY-MM-DD` format
# 2. The current year only
#
# **Expected output (example):**
# ```
# Today: 2026-06-23
# Year: 2026
# ```
#
# **💡 Hint:** `from datetime import date`, then `date.today()` and `.year`, or use `.strftime("%Y-%m-%d")`

# %%
# Task 3 – Today's Date
from datetime import date

# %% [markdown]
# ## Task 4 – Statistics on a List
#
# **Problem:** Use the `statistics` module to compute and print the **mean**, **median**, and **mode** of:
# `scores = [85, 90, 78, 90, 88, 92, 90]`
#
# **Expected output:**
# ```
# Mean: 87.57
# Median: 90
# Mode: 90
# ```
#
# **💡 Hint:** `statistics.mean()`, `statistics.median()`, `statistics.mode()` — round the mean to 2 decimals

# %%
# Task 4 – Statistics
import statistics
scores = [85, 90, 78, 90, 88, 92, 90]

# %% [markdown]
# ## 🚀 Bonus – Mini Calculator using `math`
#
# **Problem:** Write a function `calc(op, a, b)` that returns:
# - `"add"` → `a + b`
# - `"pow"` → `math.pow(a, b)`
# - `"log"` → `math.log(a, b)` (log of `a` with base `b`)
# - `"hypot"` → `math.hypot(a, b)` (Pythagorean distance)
#
# Test with each operation and print the results.
#
# **Expected output:**
# ```
# add(3, 4) = 7
# pow(2, 10) = 1024.0
# log(100, 10) = 2.0
# hypot(3, 4) = 5.0
# ```
#
# **💡 Hint:** Use `if/elif/else` to route to the right `math` function

# %%
# Bonus – Mini Calculator
import math

def calc(op, a, b):
    pass

for op in ["add", "pow", "log", "hypot"]:
    pass  # call calc() and print the result
