# %% [markdown]
# # Python Input and Output

# %% [markdown]
# # Python Output

# %% [markdown]
# We use the print() function to output data to the standard output device

# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 10
print("The value of a is", a) #python 3
print("The value of a is " + str(a))
# Out:
# The value of a is 10
# The value of a is 10

# %% [markdown]
# # Output Formatting

# %%
a = 10; b = 20 #multiple statements in single line.

print("The value of a is {} and b is {}".format(a, b))    #default
# Out:
# The value of a is 10 and b is 20

# %% [markdown]
# 1. Syntax & Readability
# Style	Example
# % formatting	"%s is %d years old" % (name, age)
# .format()	"{0} is {1} years old".format(name, age)
#
# With %, you use format specifiers (%s, %d, %f, etc.) inside the string, and provide a tuple (or single value) after the %.
#
# With .format(), you embed {} placeholders and call .format(...) with positional or named arguments.
#
# 2. Positional vs. Named Arguments
# % formatting supports only positional substitution:
#
#
# "%s scored %d points" % ("Alice", 42)
# .format() lets you use both positional and named fields:
#
#
# "{player} scored {points} points".format(player="Alice", points=42)
#
# "{0} scored {points} points".format("Alice", points=42)
# 3. Reuse & Reordering
# With %, you cant easily reuse the same value twice without repeating it in the tuple:
#
#
# "%s %s %s" % ("spam", "eggs", "ham")  # each appears once only
# With .format(), you can refer to the same argument multiple times, or reorder without changing the call:
#
#
# "{0}, {1}, and {0} again".format("spam", "eggs")
#
# 4. Advanced Formatting Options
# Alignment, width, padding, precision
#
# % supports minimal width/precision:
#
#
# "%10s" % "foo"   # right-align in width 10
# "%.2f" % 3.14159 # 2 decimal places
# .format() has a richer mini-language inside {}:
#
#
# "{:>10}".format("foo")     # right-align width 10
# "{:.2f}".format(3.14159)   # 2 decimal places
# "{:^10}".format("spam")    # centered in width 10
# "{:0>5d}".format(42)       # pad number with zeros → "00042"
# 5. Automatic Type Conversion & Safety
# %s will convert any object via str(), but other specifiers (%d, %f) require matching types (or you get a TypeError).
#
# .format() is generally more forgiving: if you use {} without a format spec, it calls str() on the object.
#
# 6. Nesting & Object Attribute Access
# .format() can drill into attributes or items:
#
#
# class P: pass
# p = P(); p.x = 42
# "Value: {0.x}".format(p)        # → "Value: 42"
# "Dict value: {d[key]}".format(d={"key": "val"})
# % has no built-in support for attribute/item lookup—you’d have to pre-extract values.
#
# 7. Deprecation & Modern Alternatives
# The % operator is considered legacy; for new code, .format() or even better, f-strings (Python 3.6+) are preferred:
#
#
# f"{name} scored {points:.2f} points"

# %%
a = 10; b = 20  #multiple statements in single line

print("The value of b is {1} and a is {0}".format(a, b)) #specify position of arguments
# Out:
# The value of b is 20 and a is 10

# %%
#we can use keyword arguments to format the string
print("Hello {name}, {greeting}".format(name="rahul", greeting="Good Morning"))
# Out:
# Hello rahul, Good Morning

# %%
#we can combine positional arguments with keyword arguments
print('The story of {0}, {1}, and {other}'.format('Bill', 'Manfred',
                                                       other='Georg'))
# Out:
# The story of Bill, Manfred, and Georg

# %% [markdown]
# # Python Input

# %% [markdown]
# want to take the input from the user. In Python, we have the input() function to allow this.

# %%
num = input("Enter a number: ")
# Out:
# Enter a number: 1

# %%
print(num)
# Out:
# 1

# %% [markdown]
# ---
# ## `print()` Function — Useful Parameters
#
# | Parameter | What it does | Example |
# |-----------|--------------|---------|
# | `sep` | Separator between arguments (default `' '`) | `print("a","b",sep="-")` → `a-b` |
# | `end` | What to print at the end (default `'\n'`) | `print("hi", end="!")` → `hi!` |
# | `file` | Where to send the output (default `sys.stdout`) | `print("x", file=f)` |
# | `flush` | Force immediate write | `print("x", flush=True)` |
#
# ```python
# print("apple", "banana", "cherry", sep=", ")   # apple, banana, cherry
# print("loading", end="...")                     # loading...
# print("done")                                   # done
# ```

# %% [markdown]
# ---
# ## f-strings — The Modern Way to Format (Python 3.6+)
#
# **f-strings** are the recommended way to format output. Just prefix the string with `f` and put expressions in `{}`.
#
# ```python
# name = "Alice"
# score = 92.357
#
# print(f"{name} scored {score}")          # Alice scored 92.357
# print(f"{name} scored {score:.2f}")      # Alice scored 92.36   (2 decimal places)
# print(f"{name:>10} | {score:<8.1f}")     # padding + alignment
# print(f"{score=}")                       # score=92.357   (debugging, 3.8+)
# print(f"Total: {2 + 3}")                 # expressions work inside {}
# ```
#
# | Format spec | Effect |
# |-------------|--------|
# | `{x:.2f}` | float with 2 decimals |
# | `{x:>10}` | right-align in width 10 |
# | `{x:<10}` | left-align in width 10 |
# | `{x:^10}` | center in width 10 |
# | `{x:05d}` | zero-pad integer to width 5 |
# | `{x:,}` | thousands separator |
# | `{x:.2%}` | percentage with 2 decimals |

# %%
# f-string demo
name = "Alice"
score = 92.357

print(f"{name} scored {score}")
print(f"{name} scored {score:.2f}")
print(f"{name:>10} | {score:<8.1f}")
print(f"Total: {2 + 3}")

# %% [markdown]
# ---
# ## Converting `input()` to Numbers
#
# `input()` **always returns a string** — even if the user types digits. Wrap it in `int()` or `float()` to get a number:
#
# ```python
# age = int(input("Age: "))           # convert to integer
# height = float(input("Height: "))   # convert to float
#
# # Multiple values on one line:
# a, b = map(int, input("Two numbers: ").split())
# ```
#
# > **Caution:** if the user types non-numeric text, `int()` raises `ValueError`. Wrap in `try/except` for safety.

# %% [markdown]
# ---
# # 📝 Assignments – Standard Input and Output
# ---

# %% [markdown]
# ## Task 1 – Custom Separators
#
# **Problem:** Print the words `"red"`, `"green"`, `"blue"` on a **single line**, separated by ` | `, and ending with `!` (no newline).
#
# **Expected output:**
# ```
# red | green | blue!
# ```
#
# **💡 Hint:** Use the `sep` and `end` parameters of `print()`.

# %%
# Task 1 – Custom Separators

# %% [markdown]
# ## Task 2 – f-string Formatting
#
# **Problem:** Given:
# ```python
# name = "Bob"
# salary = 75000.5
# tax_rate = 0.235
# ```
#
# Print exactly:
# ```
# Bob earns $75,000.50 with a tax rate of 23.50%.
# ```
#
# **💡 Hint:** `{salary:,.2f}` for thousands + 2 decimals; `{tax_rate:.2%}` for percentage.

# %%
# Task 2 – f-string Formatting
name = "Bob"
salary = 75000.5
tax_rate = 0.235

# %% [markdown]
# ## Task 3 – Number from Input
#
# **Problem:** Ask the user for a **number**, convert it to `float`, and print its **square** rounded to 2 decimals.
#
# **Expected interaction:**
# ```
# Enter a number: 4.5
# Square: 20.25
# ```
#
# **💡 Hint:** `n = float(input("Enter a number: "))` then print `f"Square: {n*n:.2f}"`.

# %%
# Task 3 – Number from Input

# %% [markdown]
# ## Task 4 – Print a Formatted Table
#
# **Problem:** Given the following data, print it as an **aligned table**.
#
# ```python
# people = [("Alice", 30, 65000), ("Bob", 25, 48000), ("Charlie", 35, 120000)]
# ```
#
# **Expected output:**
# ```
# Name       Age   Salary
# Alice      30    $65,000
# Bob        25    $48,000
# Charlie    35    $120,000
# ```
#
# **💡 Hint:** Use f-string padding like `f"{name:<10} {age:<5} ${salary:<8,}"`. Print a header row first.

# %%
# Task 4 – Formatted Table
people = [("Alice", 30, 65000), ("Bob", 25, 48000), ("Charlie", 35, 120000)]

# %% [markdown]
# ## 🚀 Bonus – Mini Calculator
#
# **Problem:** Ask the user for **two numbers** and an **operator** (`+`, `-`, `*`, `/`), then print the result formatted to 2 decimals.
#
# **Expected interaction:**
# ```
# First number: 8
# Second number: 3
# Operator (+ - * /): /
# 8.0 / 3.0 = 2.67
# ```
#
# **💡 Hint:** Convert both numbers to `float`, use `if/elif` for the operator. Handle division-by-zero gracefully.

# %%
# Bonus – Mini Calculator
a = float(input("First number: "))
b = float(input("Second number: "))
op = input("Operator (+ - * /): ")

# compute and print result here
