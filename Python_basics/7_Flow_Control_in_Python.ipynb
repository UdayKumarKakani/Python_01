# %% [markdown]
# ## If Statement
#
# ---
#
# The Python compound statement ’if’ lets you conditionally execute blocks of statements.

# %%
password = input("Enter Your password")

if password == "uday":
   print('Login successful.')
else:
   print('Login failed. Incorrect password.')
# Out:
# Enter Your passworduday
# Login successful.

# %% [markdown]
# ## For Statement:
#
# ---
#
# The for statement supports repeated execution of a statement or block of statements that is controlled by an iterable expression.

# %%
# Let us now look at a sample program in Python to demonstrate the For statement.

travelling = input("Are you travelling? Yes or No:")
while travelling == 'yes':
   num = int(input("Enter the number of people travelling:"))
   for num in range(1,num+1):
      name = input("Enter Details Name:")
      age = input("Age:")
      sex = input("Male or Female:")
      print("Details Stored",name)
      print(age)
      print(sex)
   print("Thank you!")
   travelling = input("Are you travelling? Yes or No:")
print("Please come back again.")
# Out:
# Are you travelling? Yes or No:yes
# Enter the number of people travelling:1
# Enter Details Name:uday
# Age:23
# Male or Female:male
# Details Stored uday
# 23
# male
# Thank you!
# Are you travelling? Yes or No:no
# Please come back again.

# %% [markdown]
# ## While Statement:
#
# ---
#
# The while statement in Python programming supports repeated execution of a statement or block of statements that is controlled by a conditional expression.

# %%
# Let us now look at a sample program in Python to demonstrate the While statement.
count = 0
print('Printing numbers from 0 to 9')
while (count<10):
   print('The count is ',count)
   count = count+1
print('Good Bye')
# Out:
# Printing numbers from 0 to 9
# The count is  0
# The count is  1
# The count is  2
# The count is  3
# The count is  4
# The count is  5
# The count is  6
# The count is  7
# The count is  8
# The count is  9
# Good Bye

# %% [markdown]
# ## Break Statement:
#
# ---
# The break statement is allowed only inside a loop body. When break executes, the loop terminates. If a loop is nested inside other loops, break terminates only the innermost nested loop.

# %%
for letter in 'The Quick Brown Fox. Jumps, Over The Lazy Dog':
   if letter == '.':
      break
   print ('Current Letter :', letter)
# Out:
# Current Letter : T
# Current Letter : h
# Current Letter : e
# Current Letter :
# Current Letter : Q
# Current Letter : u
# Current Letter : i
# Current Letter : c
# Current Letter : k
# Current Letter :
# Current Letter : B
# Current Letter : r
# Current Letter : o
# Current Letter : w
# Current Letter : n
# Current Letter :
# Current Letter : F
# Current Letter : o
# Current Letter : x

# %% [markdown]
# ## Continue Statement:
#
# ---
#
# The continue statement is allowed only inside a loop body. When continue executes, the current iteration of the loop body terminates, and execution continues with the next iteration of the loop.

# %%
# Let us now look at a sample program in Python to demonstrate the Continue statement.
for num in range(10, 21):
   if num % 5 == 0:
      print ("Found a multiple of 5")
      pass
      num = num + 1
      continue
   print ("Found number: ", num)
# Out:
# Found a multiple of 5
# Found number:  11
# Found number:  12
# Found number:  13
# Found number:  14
# Found a multiple of 5
# Found number:  16
# Found number:  17
# Found number:  18
# Found number:  19
# Found a multiple of 5

# %% [markdown]
# ## Pass Statement:
#
# ---
#
# The pass statement, which performs no action, can be used as a placeholder when a statement is syntactically required but you have nothing specific to do.

# %%
# Now let us look at a sample program in Python to demonstrate the Pass statement.
for num in range(10, 21):
   if num % 5 == 0:
      print ("Found a multiple of 5: ")
      pass
      num++1
   print("Found number: ", num)
# Out:
# Found a multiple of 5:
# Found number:  10
# Found number:  11
# Found number:  12
# Found number:  13
# Found number:  14
# Found a multiple of 5:
# Found number:  15
# Found number:  16
# Found number:  17
# Found number:  18
# Found number:  19
# Found a multiple of 5:
# Found number:  20

# %% [markdown]
# ---
# ## `pass` — When to Use It
#
# `pass` is a no-op placeholder. Use it when Python syntax requires a block of code but you haven't written it yet:
#
# ```python
# def future_feature():
#     pass   # TODO: implement later
#
# class EmptyClass:
#     pass
#
# for x in range(5):
#     if x == 3:
#         pass   # handle this case later
#     print(x)
# ```

# %% [markdown]
# ---
# ## `break` vs `continue` vs `pass` — Side-by-Side
#
# These three keywords affect loop execution differently:

# %%
print("--- break: stops the loop entirely ---")
for i in range(5):
    if i == 3: break
    print("break:", i)   # prints 0, 1, 2

print("\n--- continue: skips this iteration ---")
for i in range(5):
    if i == 3: continue
    print("continue:", i)  # prints 0, 1, 2, 4

print("\n--- pass: does nothing, loop runs normally ---")
for i in range(5):
    if i == 3: pass
    print("pass:", i)      # prints 0, 1, 2, 3, 4

# %% [markdown]
# ---
# # 📝 Assignments – Flow Control
# ---

# %% [markdown]
# ## Task 1 – Password Checker (for-else)
#
# **Problem:**
# ```python
# stored = "secure123"
# attempts = ["wrong", "secure123", "tryagain"]
# ```
# Loop through attempts. If an attempt matches, print `"Access granted!"` and `break`.
# If no attempt matches (loop finishes without break), print `"Access denied!"`.
#
# **💡 Hint:** `for/else` — the `else` block runs only if the loop did NOT hit a `break`

# %%
# Task 1 – Password Checker
stored = "secure123"
attempts = ["wrong", "secure123", "tryagain"]

# %% [markdown]
# ## Task 2 – Skip Vowels
#
# **Problem:** `sentence = "Python programming is fun"`
# Use `continue` to print only consonants (skip vowels: a, e, i, o, u and spaces).
#
# **Expected output:** `Pythn prgrmmng s fn`
#
# **💡 Hint:** `if letter.lower() in "aeiou ": continue`

# %%
# Task 2 – Skip Vowels
sentence = "Python programming is fun"

# %% [markdown]
# ## Task 3 – Placeholder Functions
#
# **Problem:** Create 3 placeholder functions using `pass`:
# - `calculate_tax()`
# - `send_email()`
# - `generate_report()`
#
# Call each one — they should run without errors (they just do nothing yet).
#
# This is how real developers plan features before implementing them.
#
# **💡 Hint:** Any function body must have at least one statement — `pass` satisfies this requirement

# %%
# Task 3 – Placeholder Functions
def calculate_tax():
    pass

def send_email():
    pass

def generate_report():
    pass

# Call them
calculate_tax()
send_email()
generate_report()
print("All placeholder functions ran without errors!")

# %% [markdown]
# ## Task 4 – First Common Multiple
#
# **Problem:** Use `while True` to find the first number divisible by **both 7 and 11**.
#
# **Expected output:** `First multiple of both 7 and 11: 77`
#
# **💡 Hint:** `while True: ... if num % 7 == 0 and num % 11 == 0: break; num += 1`

# %%
# Task 4 – First Common Multiple of 7 and 11
num = 1

# %% [markdown]
# ## 🚀 Bonus – Categorize Numbers
#
# **Problem:** `numbers = [4, -7, 0, 15, -3, 8, 0, -1, 22]`
# - Skip `0` with `continue`
# - `break` when you find a number > 20
# - Print `"positive"` or `"negative"` for each number processed
#
# **Expected output:**
# ```
# 4: positive
# -7: negative
# (skip 0)
# 15: positive
# -3: negative
# 8: positive
# (skip 0)
# -1: negative
# Found 22 > 20, stopping.
# ```

# %%
# Bonus – Categorize with break/continue
numbers = [4, -7, 0, 15, -3, 8, 0, -1, 22]
