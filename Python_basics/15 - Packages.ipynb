# %% [markdown]
# # Package

# %% [markdown]
# Packages are a way of structuring Python’s module namespace by using “dotted module names”.
#
# A directory must contain a file named __init__.py in order for Python to consider it as a package. This file can be left empty but we generally place the initialization code for that package in this file.

# %% [markdown]
# ![title](package.jpg)

# %% [markdown]
# # importing module from a package

# %% [markdown]
# We can import modules from packages using the dot (.) operator.

# %%
# import Gate.Image.open

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Create the parent directory (e.g., in your MyDrive)
# !mkdir -p /content/drive/MyDrive/packagedemo

# Create the package directory inside the parent directory
# !mkdir -p /content/drive/MyDrive/packagedemo/my_utilities

# %% [markdown]
# 1. Directory structure
# First, set up the directory structure. Create a parent directory, say packagedemo. Inside it, create a directory called my_utilities, which will be our package. Then, create the necessary Python files (modules) and a special __init__.py file (which can be empty, notes GeeksforGeeks) to mark my_utilities as a package.
#
#
# packagedemo/
#
# └── my_utilities/
#
#     ├── __init__.py
#     ├── math_operations.py
#     └── string_operations.py

# %% [markdown]
# math_operations.py (module)

# %%
def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

# %% [markdown]
# string_operations.py (module)

# %%
def uppercase(text):
    return text.upper()

def lowercase(text):
    return text.lower()

def reverse_string(text):
    return text[::-1]

# %% [markdown]
# __init__.py (package initializer)
#
# The __init__.py file is necessary to tell Python that the directory it resides in is a package. It can be empty, but it's often used to make certain functions or modules directly accessible when the package is imported

# %%
# packagedemo/my_utilities/__init__.py

# Example of making functions directly accessible
from .math_operations import add, subtract
from .string_operations import uppercase

# %%
import sys
sys.path.append('/Users/udaykakani/Projects/Courses/Python_01')

# %% [markdown]
# main.py (script to use the package)
#
# Finally, create a separate Python script, main.py, in the packagedemo directory to import and utilize the functions from the my_utilities package.

# %%
# packagedemo/main.py

# Import specific functions from the package
from packagedemo.my_utilities import add, uppercase, multiply

# Import a module from the package
from packagedemo.my_utilities import string_operations

# Use the functions
print(f"Addition: {add(5, 3)}") # Output: Addition: 8
print(f"Uppercase: {uppercase('hello world')}") # Output: Uppercase: HELLO WORLD

# Use a function from an imported module
print(f"Reversed string: {string_operations.reverse_string('python')}") # Output: Reversed string: nohtyp
# Out:
# Addition: 8
# Uppercase: HELLO WORLD
# Reversed string: nohtyp

# %%
import pandas as pd
import numpy as np

# Create a sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}       
df = pd.DataFrame(data)
print("Sample DataFrame:")
print(df)
# Out:
# Sample DataFrame:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %% [markdown]
# ---
# ## Package vs Module — Quick Reference
#
# | Concept | What it is | Example |
# |---------|-----------|---------|
# | **Module** | A single `.py` file | `math_operations.py` |
# | **Package** | A directory of modules with `__init__.py` | `my_utilities/` |
# | **Sub-package** | A package inside a package | `my_utilities/strings/` |
# | **`__init__.py`** | Marker file — tells Python "this is a package" | Often empty, can re-export names |
#
# ### Common Import Patterns
#
# | Syntax | Meaning |
# |--------|---------|
# | `import my_utilities` | Import whole package (runs `__init__.py`) |
# | `from my_utilities import math_operations` | Import a specific module |
# | `from my_utilities.math_operations import add` | Import a single function |
# | `from my_utilities import *` | Import everything listed in `__all__` |

# %% [markdown]
# ---
# ## The Role of `__init__.py`
#
# The `__init__.py` file makes a directory a **package**. It serves three purposes:
#
# 1. **Marker** — Python recognizes the folder as a package
# 2. **Initialization** — code in it runs when the package is first imported
# 3. **Re-exporting** — lets you "flatten" the API:
#
# ```python
# # my_utilities/__init__.py
# from .math_operations import add, subtract
# from .string_operations import uppercase
#
# # Now users can do:
# #   from my_utilities import add
# # instead of:
# #   from my_utilities.math_operations import add
# ```
#
# > **Modern note:** Python 3.3+ supports **namespace packages** (no `__init__.py` needed) but for regular packages it's still best practice to include one.

# %% [markdown]
# ---
# # 📝 Assignments – Packages
# ---

# %% [markdown]
# ## Task 1 – Draw the Folder Tree
#
# **Problem:** On paper or as a comment, sketch the file structure of a package called `shop` that contains:
# - A `products` module
# - A `customers` module
# - An `__init__.py`
#
# Then, in the code cell, write a Python multi-line string variable `tree` that holds the structure.
#
# **Expected output:**
# ```
# shop/
# ├── __init__.py
# ├── products.py
# └── customers.py
# ```
#
# **💡 Hint:** Use a triple-quoted string `tree = """..."""` then `print(tree)`

# %%
# Task 1 – Folder Tree
tree = """ """
print(tree)

# %% [markdown]
# ## Task 2 – Explain `__init__.py`
#
# **Problem:** In a code cell, store a string variable `explanation` that briefly answers (in your own words):
# 1. Why does Python need `__init__.py`?
# 2. What happens if it's missing?
# 3. What can you put inside it besides being empty?
#
# Print the explanation.
#
# **💡 Hint:** Use a multi-line string. Keep each answer to 1-2 sentences.

# %%
# Task 2 – Explain __init__.py
explanation = """
1. Python needs __init__.py because ...
2. If it is missing ...
3. Inside it you can put ...
"""
print(explanation)

# %% [markdown]
# ## Task 3 – Use a Third-Party Package
#
# **Problem:** Import the `random` package (or `math`) and use **three** different functions from it. Print the results with descriptive labels.
#
# **Expected output (example):**
# ```
# Random int 1-100: 47
# Random choice: apple
# Shuffled list: [3, 1, 2]
# ```
#
# **💡 Hint:** `random.randint`, `random.choice`, `random.shuffle` (note: `shuffle` modifies the list in place)

# %%
# Task 3 – Use a Package
import random
fruits = ["apple", "banana", "cherry"]
numbers = [1, 2, 3]

# %% [markdown]
# ## Task 4 – Aliasing Imports
#
# **Problem:** Import `datetime.datetime` as `dt`, and `math` as `m`. Print:
# - The current time using `dt.now()`
# - `m.pi` rounded to 2 decimals
#
# **Expected output (example):**
# ```
# Now: 2026-06-23 14:35:22.123456
# Pi: 3.14
# ```
#
# **💡 Hint:** `from datetime import datetime as dt` and `import math as m`

# %%
# Task 4 – Aliasing

# %% [markdown]
# ## 🚀 Bonus – Design Your Own Mini Package
#
# **Problem:** On paper (or as a long comment / multi-line string), design a package called `geometry` with:
# - An `__init__.py` that re-exports `area_circle` and `area_rectangle`
# - A `shapes.py` module containing those two functions
#
# Write the **contents** of each file as multi-line strings and print them. Pretend you're showing the file system layout.
#
# **💡 Hint:** Three multi-line strings: one for the tree, one for `__init__.py` contents, one for `shapes.py` contents.

# %%
# Bonus – Design Your Own Mini Package
tree = """ """

init_py = """ """

shapes_py = """ """

print(tree)
print("--- __init__.py ---")
print(init_py)
print("--- shapes.py ---")
print(shapes_py)
