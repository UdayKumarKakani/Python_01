# %% [markdown]
# # Day 2 — Build Tasks (spread over ~1–2 weeks)

# %% [markdown]
# ## Phase 1 — RAG pipeline
# - [ ] `POST /kb/ingest` — test with 3 real documents
# - [ ] `POST /rag/ask` — retrieve → (rerank) → generate + citations
# - [ ] `docs/demo_qa.md` — 10 realistic questions, all answer correctly
# - [ ] Deployed URL answers the 10 questions

# %% [markdown]
# ## Phase 2 — Agent workflow
# - [ ] Agent graph designed + committed to `docs/agent-graph.png`
# - [ ] LangGraph implementation with ≥2 tools + conditional edge
# - [ ] `POST /agent/run` + `GET /agent/{job_id}` with `BackgroundTasks`
# - [ ] Budget cap enforced (max steps + max tokens)
# - [ ] Langfuse trace screenshot committed

# %% [markdown]
# ## Phase 3 — Deploy + monitor
# - [ ] `@lf.observe` on every LLM call
# - [ ] `usage` table + `/usage` endpoint
# - [ ] Daily cost-cap dependency (tested by tripping it)
# - [ ] CI extended with a smoke test hitting the deployed URL
# - [ ] Two alerts: p95 latency + spend
# - [ ] Load-test numbers (p50/p95/errors) in README

# %% [markdown]
# ## Phase 4 — Demo + cost + portfolio
# - [ ] 3-minute video published (YouTube unlisted / Loom / Vimeo)
# - [ ] Cost analysis section in README (real numbers from 48h of usage)
# - [ ] Portfolio page URL with video, live demo, repo, architecture, cost, limitations
# - [ ] Elevator pitch + deep-dive story written + rehearsed
# - [ ] LinkedIn announcement posted

# %% [markdown]
# ## Stretch — Panel demo
#
# Present live to 2+ engineers. Take feedback in writing. Add it to `docs/feedback.md`.
