# %% [markdown]
# # Day 1 — Build Tasks

# %% [markdown]
# ## Task 1 — Post the pitch
#
# Commit a `README.md` with your pitch paragraph and track statement. Push.

# %% [markdown]
# ## Task 2 — Architecture doc
#
# Write `docs/ARCHITECTURE.md` with all 9 sections. Add `docs/architecture.png`.

# %% [markdown]
# ## Task 3 — Milestone issues
#
# Create GitHub Issues for each week's checkpoints. Add to a GitHub Project or Milestone.

# %% [markdown]
# ## Task 4 — Backend skeleton
#
# Set up `app/` layout. Implement `POST /auth/register`, `POST /auth/login`, `GET /me`, `GET /healthz`.

# %% [markdown]
# ## Task 5 — Tests + CI green
#
# Write `test_healthz` + `test_auth_flow`. Push. Confirm CI passes.

# %% [markdown]
# ## Task 6 — Deploy today
#
# Deploy to Render. Set env vars. Confirm `/docs` is public. Update README with the URL.
